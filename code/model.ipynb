# %%
#!/usr/bin/env python
# coding: utf-8

# # Thanks to https://www.kaggle.com/siavrez/wavenet-keras and Sergey Bryansky

# In[1]:

import tensorflow as tf
from tensorflow.keras.layers import *
import pandas as pd
import numpy as np
import random
from tensorflow.keras.callbacks import Callback, LearningRateScheduler
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras import losses, models, optimizers
import tensorflow_addons as tfa
import gc
import  tensorflow.keras.layers  as L

from sklearn.model_selection import GroupKFold
from sklearn.metrics import f1_score

import warnings
warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 500)

import os
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

for dirname, _, filenames in os.walk('../input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.


# In[2]:


# configurations and main hyperparammeters
EPOCHS = 180
NNBATCHSIZE = 16
GROUP_BATCH_SIZE = 4000
SEED = 321
LR = 0.001
SPLITS = 5

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)


# In[4]:


# read data
def read_data():
    train = pd.read_csv('../input/train_clean.csv', dtype={'time': np.float32, 'signal': np.float32, 'open_channels':np.int32})
    test  = pd.read_csv('../input/test_clean.csv', dtype={'time': np.float32, 'signal': np.float32})
    sub  = pd.read_csv('../input/sample_submission.csv', dtype={'time': np.float32})
    
    Y_train_proba = np.load("../input/Y_train_proba.npy")
    Y_test_proba = np.load("../input/Y_test_proba.npy")
    
    for i in range(11):
        train[f"proba_{i}"] = Y_train_proba[:, i]
        test[f"proba_{i}"] = Y_test_proba[:, i]
        
       
    Y_train_proba_lgb = np.load("oof_train/oof_train_lgb940.npy")
    Y_test_proba_lgb = np.load("oof_test/oof_test_lgb940.npy")
    
    
    train['lgb940'] = Y_train_proba_lgb
    test['lgb940'] = Y_test_proba_lgb
    
        
    Y_train_proba = np.load("oof_train/oof_train_seq2seq_lb940.npy")
    Y_test_proba = np.load("oof_test/oof_test_seq2seq_lb940.npy")
    
    for i in range(11):
        train[f"seq2seq_proba_{i}"] = Y_train_proba[:, i]
        test[f"seq2seq_proba_{i}"] = Y_test_proba[:, i]
        
        

    return train, test, sub

# create batches of 4000 observations
def batching(df, batch_size):
    df['group'] = df.groupby(df.index//batch_size, sort=False)['signal'].agg(['ngroup']).values
    df['group'] = df['group'].astype(np.uint16)
    return df

# normalize the data (standard scaler). We can also try other scalers for a better score!
def normalize(train, test):
    features = [col for col in train.columns if col not in ['index', 'group', 'open_channels', 'time']]
    for f in features:
        if 'prob' in f:
            continue

        train_input_mean = train[f].mean()
        train_input_sigma = train[f].std()
        train[f] = (train[f]- train_input_mean) / train_input_sigma
        test[f] = (test[f] - train_input_mean) / train_input_sigma
    return train, test

# get lead and lags features
def lag_with_pct_change(df, windows):
    for window in windows:    
        df['signal_shift_pos_' + str(window)] = df.groupby('group')['signal'].shift(window).fillna(0)
        df['signal_shift_neg_' + str(window)] = df.groupby('group')['signal'].shift(-1 * window).fillna(0)
    return df

# main module to run feature engineering. Here you may want to try and add other features and check if your score imporves :).
def run_feat_engineering(df, batch_size):
    # create batches
    df = batching(df, batch_size = batch_size)
    # create leads and lags (1, 2, 3 making them 6 features)
    df = lag_with_pct_change(df, [1, 2, 3])
    # create signal ** 2 (this is the new feature)
    # df['signal_2'] = df['signal'] ** 2
    # df['signal_value_count'] = df['signal'].map(df['signal'].value_counts(dropna=False))


    return df

# fillna with the mean and select features for training
def feature_selection(train, test):
    features = [col for col in train.columns if col not in ['index', 'group', 'open_channels', 'time']]
    train = train.replace([np.inf, -np.inf], np.nan)
    test = test.replace([np.inf, -np.inf], np.nan)
    for feature in features:
        feature_mean = pd.concat([train[feature], test[feature]], axis = 0).mean()
        train[feature] = train[feature].fillna(feature_mean)
        test[feature] = test[feature].fillna(feature_mean)
    return train, test, features

# model function (very important, you can try different arquitectures to get a better score. I believe that top public leaderboard is a 1D Conv + RNN style)
# def Classifier(shape_):
    
#     def cbr(x, out_layer, kernel, stride, dilation):
#         x = Conv1D(out_layer, kernel_size=kernel, dilation_rate=dilation, strides=stride, padding="same")(x)
#         x = BatchNormalization()(x)
#         x = Activation("relu")(x)
#         return x
    
#     def wave_block(x, filters, kernel_size, n):
#         dilation_rates = [2**i for i in range(n)]
#         x = Conv1D(filters = filters,
#                    kernel_size = 1,
#                    padding = 'same')(x)
#         res_x = x
#         for dilation_rate in dilation_rates:
#             tanh_out = Conv1D(filters = filters,
#                               kernel_size = kernel_size,
#                               padding = 'same', 
#                               activation = 'tanh', 
#                               dilation_rate = dilation_rate)(x)
#             sigm_out = Conv1D(filters = filters,
#                               kernel_size = kernel_size,
#                               padding = 'same',
#                               activation = 'sigmoid', 
#                               dilation_rate = dilation_rate)(x)
#             x = Multiply()([tanh_out, sigm_out])
#             x = Conv1D(filters = filters,
#                        kernel_size = 1,
#                        padding = 'same')(x)
#             res_x = Add()([res_x, x])
#         return res_x
    
#     inp = Input(shape = (shape_))
#     x = cbr(inp, 64, 7, 1, 1)
#     x = BatchNormalization()(x)
#     x = wave_block(x, 16, 3, 12)
#     x = BatchNormalization()(x)
#     x = wave_block(x, 32, 3, 8)
#     x = BatchNormalization()(x)
#     x = wave_block(x, 64, 3, 4)
#     x = BatchNormalization()(x)
#     x = wave_block(x, 128, 3, 2)
#     x = BatchNormalization()(x)

 

#     x = Dropout(0.2)(x)
#     out = Dense(11, activation = 'softmax', name = 'out')(x)
    
#     model = models.Model(inputs = inp, outputs = out)
    
#     opt = Adam(lr = LR)
#     opt = tfa.optimizers.SWA(opt)
#     model.compile(loss = losses.CategoricalCrossentropy(), optimizer = opt, metrics = ['accuracy'])
#     return model




# model function (very important, you can try different arquitectures to get a better score. I believe that top public leaderboard is a 1D Conv + RNN style)
def Classifier(shape_):
    
    def cbr(x, out_layer, kernel, stride, dilation):
        x = Conv1D(out_layer, kernel_size=kernel, dilation_rate=dilation, strides=stride, padding="same")(x)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        return x
    
    def wave_block(x, filters, kernel_size, n):
        dilation_rates = [2**i for i in range(n)]
        x = Conv1D(filters = filters,
                   kernel_size = 1,
                   padding = 'same')(x)
        res_x = x
        for dilation_rate in dilation_rates:
            tanh_out = Conv1D(filters = filters,
                              kernel_size = kernel_size,
                              padding = 'same', 
                              activation = 'tanh', 
                              dilation_rate = dilation_rate)(x)
            sigm_out = Conv1D(filters = filters,
                              kernel_size = kernel_size,
                              padding = 'same',
                              activation = 'sigmoid', 
                              dilation_rate = dilation_rate)(x)
            x = Multiply()([tanh_out, sigm_out])
            x = Conv1D(filters = filters,
                       kernel_size = 1,
                       padding = 'same')(x)
            res_x = Add()([res_x, x])
        return res_x
    
    inp = Input(shape = (shape_))
    x = cbr(inp, 64, 7, 1, 1)
    b = BatchNormalization()(x)
    x = wave_block(b, 16, 3, 12)
    x = BatchNormalization()(x)
    x = wave_block(x, 32, 3, 8)
    x = BatchNormalization()(x)
    x = wave_block(x, 64, 3, 4)
    x = BatchNormalization()(x)
#     x = L.concatenate([L.GlobalMaxPooling1D()(x),L.GlobalAveragePooling1D()(x)])
    
    
    x2 = wave_block(b, 32, 4, 8)
    x2 = BatchNormalization()(x2)
    x2 = wave_block(x2, 64, 4, 4)
    x2 = BatchNormalization()(x2)
#     x2 = L.concatenate([L.GlobalMaxPooling1D()(x2),L.GlobalAveragePooling1D()(x2)])



    
    x4 = L.concatenate([x,x2])
    x4 = BatchNormalization()(x4)

    x4 = Dropout(0.2)(x4)
    out = Dense(11, activation = 'softmax', name = 'out')(x4)
    
    model = models.Model(inputs = inp, outputs = out)
    
    opt = Adam(lr = LR)
    opt = tfa.optimizers.SWA(opt)
    model.compile(loss = losses.CategoricalCrossentropy(), optimizer = opt, metrics = ['accuracy'])
    return model



# function that decrease the learning as epochs increase (i also change this part of the code)
def lr_schedule(epoch):
    if epoch < 30:
        lr = LR
    elif epoch < 40:
        lr = LR / 3
    elif epoch < 50:
        lr = LR / 5
    elif epoch < 60:
        lr = LR / 7
    elif epoch < 70:
        lr = LR / 9
    elif epoch < 80:
        lr = LR / 11
    elif epoch < 90:
        lr = LR / 13
    else:
        lr = LR / 100
    return lr

# class to get macro f1 score. This is not entirely necessary but it's fun to check f1 score of each epoch (be carefull, if you use this function early stopping callback will not work)
class MacroF1(Callback):
    def __init__(self, model, inputs, targets,model_name):
        self.model = model
        self.inputs = inputs
        self.targets = np.argmax(targets, axis = 2).reshape(-1)
        self.model_name = model_name
        self.f1 = []
        self.model_weights = []
        self.f1_init = -1
        
        
        
    def on_epoch_end(self, epoch, logs):
        pred = np.argmax(self.model.predict(self.inputs), axis = 2).reshape(-1)
        score = f1_score(self.targets, pred, average = 'macro')
        print(f'F1 Macro Score: {score:.5f}')
        self.f1.append(score)
        self.model_weights.append(self.model.get_weights())
        
        
    def on_train_end(self, logs=None):
        """
        Weighted average of weights from two best epochs

        """
        f1_selected = np.argsort(self.f1)[-2:]
        print(f'Best epoch {f1_selected[1]+1} and second best epoch {f1_selected[0]+1} selected')
        swa_weights = [x * 0.3 + y * 0.7 for x, y in zip(self.model_weights[f1_selected[0]], self.model_weights[f1_selected[1]])]
        self.model.set_weights(swa_weights)
        
        pred = np.argmax(self.model.predict(self.inputs), axis = 2).reshape(-1)
        val_pred  = f1_score(self.targets, pred, average = 'macro')
        

        
        print('SWD Model F1 - {:.5f}'.format(val_pred))
        if val_pred>self.f1_init:
            self.rho_init = val_pred
            print('Save SWD Weights')
            self.model.save_weights(self.model_name)
        del self.f1, self.model_weights, swa_weights
        gc.collect()
        

# main function to perfrom groupkfold cross validation (we have 1000 vectores of 4000 rows and 8 features (columns)). Going to make 5 groups with this subgroups.
def run_cv_model_by_batch(train, test, splits, batch_col, feats, sample_submission, nn_epochs, nn_batch_size):
    
    seed_everything(SEED)
    K.clear_session()
    config = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1,inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=config)
    tf.compat.v1.keras.backend.set_session(sess)
    oof_ = np.zeros((len(train), 11)) # build out of folds matrix with 11 columns, they represent our target variables classes (from 0 to 10)
    preds_ = np.zeros((len(test), 11))
    target = ['open_channels']
    group = train['group']
    kf = GroupKFold(n_splits=5)
    splits = [x for x in kf.split(train, train[target], group)]

    new_splits = []
    for sp in splits:
        new_split = []
        new_split.append(np.unique(group[sp[0]]))
        new_split.append(np.unique(group[sp[1]]))
        new_split.append(sp[1])    
        new_splits.append(new_split)
    # pivot target columns to transform the net to a multiclass classification estructure (you can also leave it in 1 vector with sparsecategoricalcrossentropy loss function)
    tr = pd.concat([pd.get_dummies(train.open_channels), train[['group']]], axis=1)

    tr.columns = ['target_'+str(i) for i in range(11)] + ['group']
    target_cols = ['target_'+str(i) for i in range(11)]
    train_tr = np.array(list(tr.groupby('group').apply(lambda x: x[target_cols].values))).astype(np.float32)
    train = np.array(list(train.groupby('group').apply(lambda x: x[feats].values)))
    test = np.array(list(test.groupby('group').apply(lambda x: x[feats].values)))

    for n_fold, (tr_idx, val_idx, val_orig_idx) in enumerate(new_splits[0:], start=0):
        train_x, train_y = train[tr_idx], train_tr[tr_idx]
        valid_x, valid_y = train[val_idx], train_tr[val_idx]
        print(f'Our training dataset shape is {train_x.shape}')
        print(f'Our validation dataset shape is {valid_x.shape}')
        model_path = 'keras_model'
        
        model_weight = f'{model_path}/bert_fold{n_fold}.h5'


        gc.collect()
        shape_ = (None, train_x.shape[2]) # input is going to be the number of feature we are using (dimension 2 of 0, 1, 2)
        model = Classifier(shape_)
        # using our lr_schedule function
        cb_lr_schedule = LearningRateScheduler(lr_schedule)
        model.fit(train_x,train_y,
                  epochs = nn_epochs,
                  callbacks = [cb_lr_schedule, MacroF1(model, valid_x, valid_y,model_weight)], # adding custom evaluation metric for each epoch
                  batch_size = nn_batch_size,verbose = 2,
                  validation_data = (valid_x,valid_y))
        
        model.load_weights(model_weight)
        
        preds_f = model.predict(valid_x)
        f1_score_ = f1_score(np.argmax(valid_y, axis=2).reshape(-1),  np.argmax(preds_f, axis=2).reshape(-1), average = 'macro') # need to get the class with the biggest probability
        print(f'Training fold {n_fold + 1} completed. macro f1 score : {f1_score_ :1.5f}')
        preds_f = preds_f.reshape(-1, preds_f.shape[-1])
        oof_[val_orig_idx,:] += preds_f
        te_preds = model.predict(test)
        te_preds = te_preds.reshape(-1, te_preds.shape[-1])           
        preds_ += te_preds / SPLITS
    # calculate the oof macro f1_score
    f1_score_ = f1_score(np.argmax(train_tr, axis = 2).reshape(-1),  np.argmax(oof_, axis = 1), average = 'macro') # axis 2 for the 3 Dimension array and axis 1 for the 2 Domension Array (extracting the best class)
    print(f'Training completed. oof macro f1 score : {f1_score_:1.5f}')
    sample_submission['open_channels'] = np.argmax(preds_, axis = 1).astype(int)
    sample_submission.to_csv('submission_wavenet.csv', index=False, float_format='%.4f')

    np.save("oof_train_944.npy",oof_)
    np.save("oof_test_944.npy",preds_)
    
# this function run our entire program
def run_everything():
    
    print('Reading Data Started...')
    train, test, sample_submission = read_data()
    train, test = normalize(train, test)
    print('Reading and Normalizing Data Completed')
        
    print('Creating Features')
    print('Feature Engineering Started...')
    train = run_feat_engineering(train, batch_size = GROUP_BATCH_SIZE)
    test = run_feat_engineering(test, batch_size = GROUP_BATCH_SIZE)
    train, test, features = feature_selection(train, test)
    print('Feature Engineering Completed...')
        
   
    print(f'Training Wavenet model with {SPLITS} folds of GroupKFold Started...')
    run_cv_model_by_batch(train, test, SPLITS, 'group', features, sample_submission, EPOCHS, NNBATCHSIZE)
    print('Training completed...')
        
run_everything()


# In[ ]:
# Out:
# ../input/data-without-drift.zip
# ../input/Y_test_proba.npy
# ../input/train_clean_kalman.csv.zip
# ../input/train_clean.csv
# ../input/train_clean_kalman.csv
# ../input/test_clean.csv
# ../input/Y_train_proba.npy.zip
# ../input/test_clean_kalman.csv.zip
# ../input/test_clean_kalman.csv
# ../input/liverpool-ion-switching.zip
# ../input/sample_submission.csv
# ../input/Y_train_proba.npy
# ../input/train.csv
# ../input/test.csv
# ../input/Y_test_proba.npy.zip
# Reading Data Started...
# Reading and Normalizing Data Completed
# Creating Features
# Feature Engineering Started...
# Feature Engineering Completed...
# Training Wavenet model with 5 folds of GroupKFold Started...
# Our training dataset shape is (1000, 4000, 30)
# Our validation dataset shape is (250, 4000, 30)
# Train on 1000 samples, validate on 250 samples
# Epoch 1/180
# F1 Macro Score: 0.89707
# 1000/1000 - 56s - loss: 0.3710 - accuracy: 0.8916 - val_loss: 0.3190 - val_accuracy: 0.9541
# Epoch 2/180
# F1 Macro Score: 0.89867
# 1000/1000 - 19s - loss: 0.1288 - accuracy: 0.9640 - val_loss: 0.1949 - val_accuracy: 0.9595
# Epoch 3/180
# F1 Macro Score: 0.93571
# 1000/1000 - 19s - loss: 0.1150 - accuracy: 0.9660 - val_loss: 0.1231 - val_accuracy: 0.9657
# Epoch 4/180
# F1 Macro Score: 0.93629
# 1000/1000 - 19s - loss: 0.1099 - accuracy: 0.9667 - val_loss: 0.1070 - val_accuracy: 0.9661
# Epoch 5/180
# F1 Macro Score: 0.93627
# 1000/1000 - 19s - loss: 0.1059 - accuracy: 0.9670 - val_loss: 0.1024 - val_accuracy: 0.9663
# Epoch 6/180
# F1 Macro Score: 0.93681
# 1000/1000 - 19s - loss: 0.1044 - accuracy: 0.9672 - val_loss: 0.1007 - val_accuracy: 0.9664
# Epoch 7/180
# F1 Macro Score: 0.93729
# 1000/1000 - 19s - loss: 0.1012 - accuracy: 0.9674 - val_loss: 0.0992 - val_accuracy: 0.9664
# Epoch 8/180
# F1 Macro Score: 0.93827
# 1000/1000 - 19s - loss: 0.1019 - accuracy: 0.9672 - val_loss: 0.0967 - val_accuracy: 0.9669
- val_loss: 0.0817 - val_accuracy: 0.9687
# Epoch 178/180
# F1 Macro Score: 0.94097
# 1000/1000 - 19s - loss: 0.0753 - accuracy: 0.9712 - val_loss: 0.0817 - val_accuracy: 0.9687
# Epoch 179/180
# F1 Macro Score: 0.94122
# 1000/1000 - 19s - loss: 0.0757 - accuracy: 0.9711 - val_loss: 0.0818 - val_accuracy: 0.9687
# Epoch 180/180
# F1 Macro Score: 0.94118
# 1000/1000 - 19s - loss: 0.0755 - accuracy: 0.9712 - val_loss: 0.0817 - val_accuracy: 0.9687
# Best epoch 81 and second best epoch 59 selected
# SWD Model F1 - 0.94146
# Save SWD Weights
# Training fold 1 completed. macro f1 score : 0.94146
# Our training dataset shape is (1000, 4000, 30)
# Our validation dataset shape is (250, 4000, 30)
# Train on 1000 samples, validate on 250 samples
# Epoch 1/180
# F1 Macro Score: 0.86614
# 1000/1000 - 54s - loss: 0.3583 - accuracy: 0.8915 - val_loss: 0.3493 - val_accuracy: 0.9382
# Epoch 2/180
# F1 Macro Score: 0.93629
# 1000/1000 - 19s - loss: 0.1317 - accuracy: 0.9635 - val_loss: 0.1777 - val_accuracy: 0.9675
# Epoch 3/180
# F1 Macro Score: 0.93558
# 1000/1000 - 19s - loss: 0.1168 - accuracy: 0.9656 - val_loss: 0.1199 - val_accuracy: 0.9681
# Epoch 4/180
# F1 Macro Score: 0.93854
# 1000/1000 - 19s - loss: 0.1115 - accuracy: 0.9661 - val_loss: 0.0990 - val_accuracy: 0.9690
# Epoch 5/180
# F1 Macro Score: 0.93824
# 1000/1000 - 19s - loss: 0.1086 - accuracy: 0.9664 - val_loss: 0.0949 - val_accuracy: 0.9689
# Epoch 6/180
# F1 Macro Score: 0.93918
# 1000/1000 - 18s - loss: 0.1063 - accuracy: 0.9665 - val_loss: 0.0918 - val_accuracy: 0.9693
# Epoch 7/180
# F1 Macro Score: 0.93921
# 1000/1000 - 19s - loss: 0.1043 - accuracy: 0.9666 - val_loss: 0.0901 - val_accuracy: 0.9694
# Epoch 8/180
# F1 Macro Score: 0.93838
# 1000/1000 - 19s - loss: 0.1028 - accuracy: 0.9668 - val_loss: 0.0914 - val_accuracy: 0.9690
# Epoch 9/180
# F1 Macro Score: 0.93880
# 1000/1000 - 19s - loss: 0.1000 - accuracy: 0.9669 - val_loss: 0.0883 - val_accuracy: 0.9694
# Epoch 10/180
# F1 Macro Score: 0.93826
# 1000/1000 - 18s - loss: 0.1055 - accuracy: 0.9661 - val_loss: 0.0939 - val_accuracy: 0.9690
# Epoch 11/180
# F1 Macro Score: 0.93758
# 1000/1000 - 18s - loss: 0.0997 - accuracy: 0.9669 - val_loss: 0.0909 - val_accuracy: 0.9687
# Epoch 12/180
# F1 Macro Score: 0.93925
# 1000/1000 - 19s - loss: 0.0976 - accuracy: 0.9670 - val_loss: 0.0895 - val_accuracy: 0.9693
# Epoch 13/180
# F1 Macro Score: 0.93936
# 1000/1000 - 19s - loss: 0.0976 - accuracy: 0.9671 - val_loss: 0.0853 - val_accuracy: 0.9696
# Epoch 14/180
# F1 Macro Score: 0.93936
# 1000/1000 - 19s - loss: 0.0954 - accuracy: 0.9671 - val_loss: 0.0852 - val_accuracy: 0.9695
# Epoch 15/180
# F1 Macro Score: 0.93843
# 1000/1000 - 19s - loss: 0.0965 - accuracy: 0.9669 - val_loss: 0.0872 - val_accuracy: 0.9692
# F1 Macro Score: 0.94082
# 1000/1000 - 19s - loss: 0.0814 - accuracy: 0.9695 - val_loss: 0.0785 - val_accuracy: 0.9706
# Epoch 35/180
# F1 Macro Score: 0.94230
# 1000/1000 - 19s - loss: 0.0819 - accuracy: 0.9694 - val_loss: 0.0763 - val_accuracy: 0.9712
# Epoch 36/180
# F1 Macro Score: 0.94163
# 1000/1000 - 19s - loss: 0.0812 - accuracy: 0.9696 - val_loss: 0.0768 - val_accuracy: 0.9711
# Epoch 37/180
# F1 Macro Score: 0.94247
# 1000/1000 - 19s - loss: 0.0813 - accuracy: 0.9696 - val_loss: 0.0760 - val_accuracy: 0.9713
# Epoch 38/180
# F1 Macro Score: 0.94230
# 1000/1000 - 19s - loss: 0.0816 - accuracy: 0.9695 - val_loss: 0.0762 - val_accuracy: 0.9713
# Epoch 39/180
# F1 Macro Score: 0.94242
# 1000/1000 - 18s - loss: 0.0810 - accuracy: 0.9696 - val_loss: 0.0763 - val_accuracy: 0.9713
# Epoch 40/180
# F1 Macro Score: 0.94168
# 1000/1000 - 19s - loss: 0.0808 - accuracy: 0.9696 - val_loss: 0.0771 - val_accuracy: 0.9710
# Epoch 41/180
# F1 Macro Score: 0.94255
# 1000/1000 - 18s - loss: 0.0804 - accuracy: 0.9697 - val_loss: 0.0758 - val_accuracy: 0.9713
# Epoch 42/180
# F1 Macro Score: 0.94257
# 1000/1000 - 19s - loss: 0.0803 - accuracy: 0.9698 - val_loss: 0.0757 - val_accuracy: 0.9713
# Epoch 43/180
# F1 Macro Score: 0.94170
# 1000/1000 - 19s - loss: 0.0807 - accuracy: 0.9697 - val_loss: 0.0771 - val_accuracy: 0.9709
# Epoch 44/180
# F1 Macro Score: 0.94242
# 1000/1000 - 19s - loss: 0.0801 - accuracy: 0.9698 - val_loss: 0.0759 - val_accuracy: 0.9713
# Epoch 45/180
# F1 Macro Score: 0.94285
# 1000/1000 - 19s - loss: 0.0805 - accuracy: 0.9698 - val_loss: 0.0757 - val_accuracy: 0.9715
# Epoch 46/180
# F1 Macro Score: 0.94259
# 1000/1000 - 19s - loss: 0.0803 - accuracy: 0.9698 - val_loss: 0.0757 - val_accuracy: 0.9714
# Epoch 47/180
# F1 Macro Score: 0.94130
# 1000/1000 - 19s - loss: 0.0803 - accuracy: 0.9698 - val_loss: 0.0771 - val_accuracy: 0.9708
# Epoch 48/180
# F1 Macro Score: 0.94222
# 1000/1000 - 19s - loss: 0.0804 - accuracy: 0.9697 - val_loss: 0.0763 - val_accuracy: 0.9712
# Epoch 49/180
# F1 Macro Score: 0.94266
# 1000/1000 - 18s - loss: 0.0800 - accuracy: 0.9699 - val_loss: 0.0759 - val_accuracy: 0.9714
# Epoch 50/180
# F1 Macro Score: 0.94262
# 1000/1000 - 18s - loss: 0.0797 - accuracy: 0.9699 - val_loss: 0.0756 - val_accuracy: 0.9713
# Epoch 51/180
# F1 Macro Score: 0.94253
# 1000/1000 - 19s - loss: 0.0794 - accuracy: 0.9700 - val_loss: 0.0757 - val_accuracy: 0.9713
# Epoch 52/180
# F1 Macro Score: 0.94249
# 1000/1000 - 19s - loss: 0.0792 - accuracy: 0.9701 - val_loss: 0.0755 - val_accuracy: 0.9714
# Epoch 53/180
# F1 Macro Score: 0.94244
# 1000/1000 - 18s - loss: 0.0793 - accuracy: 0.9700 - val_loss: 0.0758 - val_accuracy: 0.9712
# Epoch 54/180
# F1 Macro Score: 0.94255
# 1000/1000 - 18s - loss: 0.0793 - accuracy: 0.9700 - val_loss: 0.0757 - val_accuracy: 0.9713
# Epoch 55/180
# F1 Macro Score: 0.94131
# 1000/1000 - 19s - loss: 0.0796 - accuracy: 0.9700 - val_loss: 0.0772 - val_accuracy: 0.9709
# Epoch 56/180
# F1 Macro Score: 0.94224
# 1000/1000 - 19s - loss: 0.0793 - accuracy: 0.9701 - val_loss: 0.0757 - val_accuracy: 0.9713
# Epoch 57/180
# F1 Macro Score: 0.94210
# 1000/1000 - 19s - loss: 0.0790 - accuracy: 0.9701 - val_loss: 0.0759 - val_accuracy: 0.9712
# Epoch 58/180
# F1 Macro Score: 0.94239
# 1000/1000 - 19s - loss: 0.0788 - accuracy: 0.9702 - val_loss: 0.0754 - val_accuracy: 0.9714
# Epoch 59/180
# F1 Macro Score: 0.94278
# 1000/1000 - 19s - loss: 0.0795 - accuracy: 0.9700 - val_loss: 0.0757 - val_accuracy: 0.9714
# Epoch 60/180
# F1 Macro Score: 0.94293
# 1000/1000 - 18s - loss: 0.0794 - accuracy: 0.9700 - val_loss: 0.0754 - val_accuracy: 0.9715
# Epoch 61/180
# F1 Macro Score: 0.94260
# 1000/1000 - 19s - loss: 0.0790 - accuracy: 0.9701 - val_loss: 0.0755 - val_accuracy: 0.9714
# Epoch 62/180
# F1 Macro Score: 0.94264
# 1000/1000 - 19s - loss: 0.0790 - accuracy: 0.9702 - val_loss: 0.0754 - val_accuracy: 0.9714
# Epoch 63/180
# F1 Macro Score: 0.94251
# 1000/1000 - 19s - loss: 0.0786 - accuracy: 0.9702 - val_loss: 0.0756 - val_accuracy: 0.9713
# Epoch 64/180
# F1 Macro Score: 0.94209
# 1000/1000 - 19s - loss: 0.0790 - accuracy: 0.9701 - val_loss: 0.0762 - val_accuracy: 0.9711
# Epoch 65/180
# F1 Macro Score: 0.94259
# 1000/1000 - 19s - loss: 0.0785 - accuracy: 0.9702 - val_loss: 0.0754 - val_accuracy: 0.9714
# Epoch 66/180
# F1 Macro Score: 0.94228
# 1000/1000 - 19s - loss: 0.0787 - accuracy: 0.9702 - val_loss: 0.0761 - val_accuracy: 0.9712
# Epoch 67/180
# F1 Macro Score: 0.94240
# 1000/1000 - 18s - loss: 0.0786 - accuracy: 0.9703 - val_loss: 0.0755 - val_accuracy: 0.9713
# Epoch 68/180
# F1 Macro Score: 0.94227
# 1000/1000 - 19s - loss: 0.0784 - accuracy: 0.9702 - val_loss: 0.0754 - val_accuracy: 0.9712
# Epoch 69/180
# F1 Macro Score: 0.94249
# 1000/1000 - 18s - loss: 0.0785 - accuracy: 0.9702 - val_loss: 0.0754 - val_accuracy: 0.9714
# Epoch 70/180
# F1 Macro Score: 0.94247
# 1000/1000 - 19s - loss: 0.0783 - accuracy: 0.9703 - val_loss: 0.0756 - val_accuracy: 0.9713
# Epoch 71/180
# F1 Macro Score: 0.94219
# 1000/1000 - 18s - loss: 0.0785 - accuracy: 0.9703 - val_loss: 0.0757 - val_accuracy: 0.9712
# Epoch 72/180
# F1 Macro Score: 0.94220
# 1000/1000 - 19s - loss: 0.0781 - accuracy: 0.9703 - val_loss: 0.0759 - val_accuracy: 0.9712
# Epoch 73/180
# F1 Macro Score: 0.94260
# 1000/1000 - 19s - loss: 0.0782 - accuracy: 0.9703 - val_loss: 0.0753 - val_accuracy: 0.9714
# Epoch 74/180
# F1 Macro Score: 0.94219
# 1000/1000 - 19s - loss: 0.0784 - accuracy: 0.9703 - val_loss: 0.0757 - val_accuracy: 0.9712
# Epoch 75/180
# F1 Macro Score: 0.94227
# 1000/1000 - 19s - loss: 0.0782 - accuracy: 0.9704 - val_loss: 0.0754 - val_accuracy: 0.9714
# Epoch 76/180
# F1 Macro Score: 0.94065
# 1000/1000 - 18s - loss: 0.0780 - accuracy: 0.9704 - val_loss: 0.0772 - val_accuracy: 0.9709
# Epoch 77/180
# F1 Macro Score: 0.94246
# 1000/1000 - 19s - loss: 0.0781 - accuracy: 0.9704 - val_loss: 0.0754 - val_accuracy: 0.9714
# Epoch 78/180
# F1 Macro Score: 0.94221
# 1000/1000 - 18s - loss: 0.0785 - accuracy: 0.9703 - val_loss: 0.0759 - val_accuracy: 0.9712
# Epoch 79/180
# F1 Macro Score: 0.94238
# 1000/1000 - 19s - loss: 0.0780 - accuracy: 0.9704 - val_loss: 0.0755 - val_accuracy: 0.9713
# Epoch 80/180
# F1 Macro Score: 0.94234
# 1000/1000 - 19s - loss: 0.0779 - accuracy: 0.9704 - val_loss: 0.0755 - val_accuracy: 0.9713
# Epoch 81/180
# F1 Macro Score: 0.94229
# 1000/1000 - 19s - loss: 0.0780 - accuracy: 0.9704 - val_loss: 0.0758 - val_accuracy: 0.9712
# Epoch 82/180
# F1 Macro Score: 0.94236
# 1000/1000 - 18s - loss: 0.0781 - accuracy: 0.9703 - val_loss: 0.0758 - val_accuracy: 0.9713
# Epoch 83/180
# F1 Macro Score: 0.94220
# 1000/1000 - 19s - loss: 0.0777 - accuracy: 0.9705 - val_loss: 0.0755 - val_accuracy: 0.9712
# Epoch 84/180
# F1 Macro Score: 0.94194
# 1000/1000 - 19s - loss: 0.0778 - accuracy: 0.9705 - val_loss: 0.0757 - val_accuracy: 0.9712
# Epoch 85/180
# F1 Macro Score: 0.94242
# 1000/1000 - 19s - loss: 0.0776 - accuracy: 0.9705 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 86/180
# F1 Macro Score: 0.94227
# 1000/1000 - 19s - loss: 0.0776 - accuracy: 0.9705 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 87/180
# F1 Macro Score: 0.94243
# 1000/1000 - 19s - loss: 0.0777 - accuracy: 0.9704 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 88/180
# F1 Macro Score: 0.94208
# Epoch 125/180
# F1 Macro Score: 0.94253
# 1000/1000 - 18s - loss: 0.0768 - accuracy: 0.9707 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 126/180
# F1 Macro Score: 0.94247
# 1000/1000 - 18s - loss: 0.0773 - accuracy: 0.9706 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 127/180
# F1 Macro Score: 0.94234
# 1000/1000 - 19s - loss: 0.0773 - accuracy: 0.9706 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 128/180
# F1 Macro Score: 0.94226
# 1000/1000 - 19s - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0.0756 - val_accuracy: 0.9712
# Epoch 129/180
# F1 Macro Score: 0.94247
# 1000/1000 - 19s - loss: 0.0770 - accuracy: 0.9707 - val_loss: 0.0753 - val_accuracy: 0.9714
# Epoch 130/180
# F1 Macro Score: 0.94253
# 1000/1000 - 19s - loss: 0.0767 - accuracy: 0.9707 - val_loss: 0.0753 - val_accuracy: 0.9714
# Epoch 131/180
# F1 Macro Score: 0.94256
# 1000/1000 - 19s - loss: 0.0771 - accuracy: 0.9706 - val_loss: 0.0753 - val_accuracy: 0.9714
# Epoch 132/180
# F1 Macro Score: 0.94237
# 1000/1000 - 19s - loss: 0.0767 - accuracy: 0.9707 - val_loss: 0.0753 - val_accuracy: 0.9713
# Epoch 133/180
# F1 Macro Score: 0.94252
# 1000/1000 - 19s - loss: 0.0766 - accuracy: 0.9708 - val_loss: 0.0753 - val_accuracy: 0.9713
# Epoch 134/180
# F1 Macro Score: 0.94245
# 1000/1000 - 18s - loss: 0.0767 - accuracy: 0.9708 - val_loss: 0.0753 - val_accuracy: 0.9713
# Epoch 135/180
# F1 Macro Score: 0.94247
# 1000/1000 - 19s - loss: 0.0768 - accuracy: 0.9707 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 136/180
# F1 Macro Score: 0.94241
# 1000/1000 - 18s - loss: 0.0771 - accuracy: 0.9706 - val_loss: 0.0755 - val_accuracy: 0.9713
# Epoch 137/180
# F1 Macro Score: 0.94250
# 1000/1000 - 19s - loss: 0.0768 - accuracy: 0.9707 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 138/180
# F1 Macro Score: 0.94245
# 1000/1000 - 19s - loss: 0.0765 - accuracy: 0.9708 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 139/180
# F1 Macro Score: 0.94250
# 1000/1000 - 19s - loss: 0.0767 - accuracy: 0.9708 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 140/180
# F1 Macro Score: 0.94252
# 1000/1000 - 19s - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0.0753 - val_accuracy: 0.9714
# Epoch 141/180
# F1 Macro Score: 0.94254
# 1000/1000 - 19s - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0.0753 - val_accuracy: 0.9714
# Epoch 142/180
# F1 Macro Score: 0.94248
# 1000/1000 - 18s - loss: 0.0768 - accuracy: 0.9707 - val_loss: 0.0753 - val_accuracy: 0.9713
# Epoch 143/180
# F1 Macro Score: 0.94252
# 1000/1000 - 19s - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0.0753 - val_accuracy: 0.9713
# Epoch 144/180
# F1 Macro Score: 0.94248
# 1000/1000 - 19s - loss: 0.0767 - accuracy: 0.9708 - val_loss: 0.0753 - val_accuracy: 0.9713
# Epoch 145/180
# F1 Macro Score: 0.94249
# 1000/1000 - 19s - loss: 0.0766 - accuracy: 0.9708 - val_loss: 0.0753 - val_accuracy: 0.9713
# Epoch 146/180
# F1 Macro Score: 0.94250
# 1000/1000 - 18s - loss: 0.0768 - accuracy: 0.9707 - val_loss: 0.0753 - val_accuracy: 0.9713
# Epoch 147/180
# F1 Macro Score: 0.94234
# 1000/1000 - 19s - loss: 0.0765 - accuracy: 0.9708 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 148/180
# F1 Macro Score: 0.94247
# 1000/1000 - 19s - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0.0753 - val_accuracy: 0.9713
# Epoch 149/180
# F1 Macro Score: 0.94246
# 1000/1000 - 19s - loss: 0.0767 - accuracy: 0.9708 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 150/180
# F1 Macro Score: 0.94252
# 1000/1000 - 19s - loss: 0.0767 - accuracy: 0.9708 - val_loss: 0.0753 - val_accuracy: 0.9713
# Epoch 151/180
# F1 Macro Score: 0.94252
# 1000/1000 - 19s - loss: 0.0766 - accuracy: 0.9708 - val_loss: 0.0753 - val_accuracy: 0.9714
# Epoch 152/180
# F1 Macro Score: 0.94253
# 1000/1000 - 19s - loss: 0.0770 - accuracy: 0.9707 - val_loss: 0.0753 - val_accuracy: 0.9714
# Epoch 153/180
# F1 Macro Score: 0.94257
# 1000/1000 - 19s - loss: 0.0767 - accuracy: 0.9707 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 154/180
# F1 Macro Score: 0.94253
# 1000/1000 - 19s - loss: 0.0768 - accuracy: 0.9707 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 155/180
# F1 Macro Score: 0.94250
# 1000/1000 - 19s - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0.0755 - val_accuracy: 0.9713
# Epoch 156/180
# F1 Macro Score: 0.94241
# 1000/1000 - 19s - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 157/180
# F1 Macro Score: 0.94242
# 1000/1000 - 19s - loss: 0.0766 - accuracy: 0.9707 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 158/180
# F1 Macro Score: 0.94238
# 1000/1000 - 19s - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0.0756 - val_accuracy: 0.9713
# Epoch 159/180
# F1 Macro Score: 0.94238
# 1000/1000 - 19s - loss: 0.0767 - accuracy: 0.9707 - val_loss: 0.0755 - val_accuracy: 0.9713
# Epoch 160/180
# F1 Macro Score: 0.94242
# 1000/1000 - 19s - loss: 0.0767 - accuracy: 0.9707 - val_loss: 0.0753 - val_accuracy: 0.9713
# Epoch 161/180
# F1 Macro Score: 0.94242
# 1000/1000 - 19s - loss: 0.0766 - accuracy: 0.9708 - val_loss: 0.0753 - val_accuracy: 0.9713
# Epoch 162/180
# F1 Macro Score: 0.94228
# 1000/1000 - 18s - loss: 0.0766 - accuracy: 0.9708 - val_loss: 0.0756 - val_accuracy: 0.9713
# Epoch 163/180
# F1 Macro Score: 0.94242
# 1000/1000 - 19s - loss: 0.0770 - accuracy: 0.9707 - val_loss: 0.0755 - val_accuracy: 0.9713
# Epoch 164/180
# F1 Macro Score: 0.94249
# 1000/1000 - 18s - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 165/180
# F1 Macro Score: 0.94229
# 1000/1000 - 18s - loss: 0.0766 - accuracy: 0.9707 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 166/180
# F1 Macro Score: 0.94247
# 1000/1000 - 18s - loss: 0.0764 - accuracy: 0.9708 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 167/180
# F1 Macro Score: 0.94226
# 1000/1000 - 19s - loss: 0.0767 - accuracy: 0.9707 - val_loss: 0.0755 - val_accuracy: 0.9713
# Epoch 168/180
# F1 Macro Score: 0.94238
# 1000/1000 - 19s - loss: 0.0767 - accuracy: 0.9708 - val_loss: 0.0756 - val_accuracy: 0.9713
# Epoch 169/180
# F1 Macro Score: 0.94246
# 1000/1000 - 19s - loss: 0.0766 - accuracy: 0.9708 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 170/180
# F1 Macro Score: 0.94235
# 1000/1000 - 19s - loss: 0.0765 - accuracy: 0.9708 - val_loss: 0.0755 - val_accuracy: 0.9713
# Epoch 171/180
# F1 Macro Score: 0.94237
# 1000/1000 - 19s - loss: 0.0767 - accuracy: 0.9708 - val_loss: 0.0755 - val_accuracy: 0.9713
# Epoch 172/180
# F1 Macro Score: 0.94251
# 1000/1000 - 19s - loss: 0.0765 - accuracy: 0.9708 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 173/180
# F1 Macro Score: 0.94252
# 1000/1000 - 19s - loss: 0.0766 - accuracy: 0.9708 - val_loss: 0.0753 - val_accuracy: 0.9714
# Epoch 174/180
# F1 Macro Score: 0.94241
# 1000/1000 - 19s - loss: 0.0765 - accuracy: 0.9708 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 175/180
# F1 Macro Score: 0.94239
# 1000/1000 - 19s - loss: 0.0765 - accuracy: 0.9708 - val_loss: 0.0753 - val_accuracy: 0.9713
# Epoch 176/180
# F1 Macro Score: 0.94249
# 1000/1000 - 19s - loss: 0.0767 - accuracy: 0.9708 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 177/180
# F1 Macro Score: 0.94245
# 1000/1000 - 18s - loss: 0.0766 - accuracy: 0.9708 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 178/180
# F1 Macro Score: 0.94237
# 1000/1000 - 19s - loss: 0.0765 - accuracy: 0.9708 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 179/180
# F1 Macro Score: 0.94247
# 1000/1000 - 19s - loss: 0.0766 - accuracy: 0.9708 - val_loss: 0.0754 - val_accuracy: 0.9713
# Epoch 180/180
# F1 Macro Score: 0.94241
# 1000/1000 - 19s - loss: 0.0766 - accuracy: 0.9707 - val_loss: 0.0755 - val_accuracy: 0.9713
# Best epoch 60 and second best epoch 45 selected
# SWD Model F1 - 0.94293
# Save SWD Weights
# Training fold 2 completed. macro f1 score : 0.94293
# Our training dataset shape is (1000, 4000, 30)
# Our validation dataset shape is (250, 4000, 30)
# Train on 1000 samples, validate on 250 samples
# Epoch 1/180
# F1 Macro Score: 0.81878
# ...
# Epoch 14/180
# F1 Macro Score: 0.93757
# 1000/1000 - 19s - loss: 0.0956 - accuracy: 0.9675 - val_loss: 0.0914 - val_accuracy: 0.9676
# Epoch 15/180
# F1 Macro Score: 0.93609
# 1000/1000 - 19s - loss: 0.0942 - accuracy: 0.9677 - val_loss: 0.0934 - val_accuracy: 0.9668
# Epoch 16/180
# F1 Macro Score: 0.93688
# 1000/1000 - 18s - loss: 0.0932 - accuracy: 0.9677 - val_loss: 0.0914 - val_accuracy: 0.9673
# Epoch 17/180
# F1 Macro Score: 0.93516
# 1000/1000 - 18s - loss: 0.0930 - accuracy: 0.9676 - val_loss: 0.0916 - val_accuracy: 0.9671
# Epoch 18/180
# F1 Macro Score: 0.93793
# 1000/1000 - 19s - loss: 0.0919 - accuracy: 0.9678 - val_loss: 0.0889 - val_accuracy: 0.9677
# Epoch 19/180
# F1 Macro Score: 0.93472
# 1000/1000 - 19s - loss: 0.0914 - accuracy: 0.9678 - val_loss: 0.0938 - val_accuracy: 0.9663
# Epoch 20/180
# F1 Macro Score: 0.93714
# 1000/1000 - 19s - loss: 0.0917 - accuracy: 0.9676 - val_loss: 0.0901 - val_accuracy: 0.9673
# Epoch 21/180
# F1 Macro Score: 0.93754
# 1000/1000 - 19s - loss: 0.0905 - accuracy: 0.9677 - val_loss: 0.0884 - val_accuracy: 0.9677
# Epoch 22/180
# F1 Macro Score: 0.93672
# 1000/1000 - 19s - loss: 0.0905 - accuracy: 0.9678 - val_loss: 0.0892 - val_accuracy: 0.9672
# Epoch 23/180
# F1 Macro Score: 0.93706
# 1000/1000 - 19s - loss: 0.0894 - accuracy: 0.9679 - val_loss: 0.0889 - val_accuracy: 0.9673
# Epoch 24/180
# F1 Macro Score: 0.93652
# 1000/1000 - 19s - loss: 0.0893 - accuracy: 0.9678 - val_loss: 0.0891 - val_accuracy: 0.9672
# Epoch 25/180
# F1 Macro Score: 0.93524
# 1000/1000 - 19s - loss: 0.0905 - accuracy: 0.9677 - val_loss: 0.0882 - val_accuracy: 0.9674
# Epoch 26/180
# F1 Macro Score: 0.93788
# 1000/1000 - 18s - loss: 0.0878 - accuracy: 0.9681 - val_loss: 0.0862 - val_accuracy: 0.9679
# Epoch 27/180
# F1 Macro Score: 0.93776
# 1000/1000 - 19s - loss: 0.0875 - accuracy: 0.9682 - val_loss: 0.0868 - val_accuracy: 0.9679
# Epoch 28/180
# F1 Macro Score: 0.93620
# 1000/1000 - 19s - loss: 0.0873 - accuracy: 0.9682 - val_loss: 0.0896 - val_accuracy: 0.9671
# Epoch 29/180
# F1 Macro Score: 0.93776
# 1000/1000 - 19s - loss: 0.0871 - accuracy: 0.9682 - val_loss: 0.0858 - val_accuracy: 0.9679
# Epoch 30/180
# F1 Macro Score: 0.93761
# 1000/1000 - 19s - loss: 0.0864 - accuracy: 0.9684 - val_loss: 0.0863 - val_accuracy: 0.9679
# Epoch 31/180
# F1 Macro Score: 0.93793
# 1000/1000 - 19s - loss: 0.0846 - accuracy: 0.9688 - val_loss: 0.0848 - val_accuracy: 0.9681
# Epoch 32/180
# F1 Macro Score: 0.93806
# 1000/1000 - 19s - loss: 0.0839 - accuracy: 0.9689 - val_loss: 0.0844 - val_accuracy: 0.9681
# Epoch 33/180
# F1 Macro Score: 0.93834
# 1000/1000 - 19s - loss: 0.0840 - accuracy: 0.9689 - val_loss: 0.0841 - val_accuracy: 0.9683
# Epoch 34/180
# F1 Macro Score: 0.93868
# 1000/1000 - 19s - loss: 0.0836 - accuracy: 0.9689 - val_loss: 0.0839 - val_accuracy: 0.9684
# Epoch 35/180
# F1 Macro Score: 0.93850
# 1000/1000 - 18s - loss: 0.0836 - accuracy: 0.9689 - val_loss: 0.0840 - val_accuracy: 0.9683
# Epoch 36/180
# F1 Macro Score: 0.93884
# 1000/1000 - 19s - loss: 0.0828 - accuracy: 0.9691 - val_loss: 0.0834 - val_accuracy: 0.9685
# Epoch 37/180
# F1 Macro Score: 0.93944
# 1000/1000 - 19s - loss: 0.0830 - accuracy: 0.9691 - val_loss: 0.0828 - val_accuracy: 0.9687
# Epoch 38/180
# F1 Macro Score: 0.93870
# 1000/1000 - 19s - loss: 0.0829 - accuracy: 0.9692 - val_loss: 0.0834 - val_accuracy: 0.9685
# Epoch 39/180
# F1 Macro Score: 0.93883
# 1000/1000 - 19s - loss: 0.0826 - accuracy: 0.9692 - val_loss: 0.0833 - val_accuracy: 0.9685
# Epoch 40/180
# F1 Macro Score: 0.93962
# 1000/1000 - 19s - loss: 0.0821 - accuracy: 0.9694 - val_loss: 0.0825 - val_accuracy: 0.9688
# Epoch 41/180
# F1 Macro Score: 0.93950
# 1000/1000 - 19s - loss: 0.0811 - accuracy: 0.9696 - val_loss: 0.0821 - val_accuracy: 0.9687
# Epoch 42/180
# F1 Macro Score: 0.93899
# 1000/1000 - 18s - loss: 0.0811 - accuracy: 0.9696 - val_loss: 0.0829 - val_accuracy: 0.9686
# Epoch 43/180
# F1 Macro Score: 0.93934
# 1000/1000 - 19s - loss: 0.0811 - accuracy: 0.9697 - val_loss: 0.0827 - val_accuracy: 0.9687
# Epoch 44/180
# F1 Macro Score: 0.93995
# 1000/1000 - 19s - loss: 0.0804 - accuracy: 0.9698 - val_loss: 0.0820 - val_accuracy: 0.9690
# Epoch 45/180
# F1 Macro Score: 0.93987
# 1000/1000 - 19s - loss: 0.0813 - accuracy: 0.9697 - val_loss: 0.0819 - val_accuracy: 0.9689
# Epoch 46/180
# F1 Macro Score: 0.93931
# 1000/1000 - 19s - loss: 0.0811 - accuracy: 0.9697 - val_loss: 0.0831 - val_accuracy: 0.9686
# Epoch 47/180
# F1 Macro Score: 0.93919
# 1000/1000 - 19s - loss: 0.0811 - accuracy: 0.9697 - val_loss: 0.0823 - val_accuracy: 0.9687
# Epoch 48/180
# F1 Macro Score: 0.93936
# 1000/1000 - 19s - loss: 0.0805 - accuracy: 0.9698 - val_loss: 0.0820 - val_accuracy: 0.9688
# Epoch 49/180
# F1 Macro Score: 0.93942
# 1000/1000 - 19s - loss: 0.0802 - accuracy: 0.9700 - val_loss: 0.0822 - val_accuracy: 0.9688
# Epoch 50/180
# F1 Macro Score: 0.93988
# 1000/1000 - 19s - loss: 0.0803 - accuracy: 0.9698 - val_loss: 0.0816 - val_accuracy: 0.9690
# Epoch 51/180
# F1 Macro Score: 0.94041
# 1000/1000 - 19s - loss: 0.0797 - accuracy: 0.9700 - val_loss: 0.0809 - val_accuracy: 0.9692
# Epoch 52/180
# F1 Macro Score: 0.93975
# 1000/1000 - 18s - loss: 0.0796 - accuracy: 0.9701 - val_loss: 0.0812 - val_accuracy: 0.9690
# Epoch 53/180
# F1 Macro Score: 0.94029
# 1000/1000 - 18s - loss: 0.0799 - accuracy: 0.9699 - val_loss: 0.0810 - val_accuracy: 0.9691
# Epoch 54/180
# F1 Macro Score: 0.94012
# 1000/1000 - 19s - loss: 0.0795 - accuracy: 0.9701 - val_loss: 0.0809 - val_accuracy: 0.9692
# Epoch 55/180
# F1 Macro Score: 0.94020
# 1000/1000 - 19s - loss: 0.0796 - accuracy: 0.9701 - val_loss: 0.0812 - val_accuracy: 0.9691
# Epoch 56/180
# F1 Macro Score: 0.94037
# 1000/1000 - 18s - loss: 0.0795 - accuracy: 0.9701 - val_loss: 0.0811 - val_accuracy: 0.9692
# Epoch 57/180
# F1 Macro Score: 0.94030
# 1000/1000 - 19s - loss: 0.0790 - accuracy: 0.9702 - val_loss: 0.0810 - val_accuracy: 0.9692
# Epoch 58/180
# F1 Macro Score: 0.93925
# 1000/1000 - 19s - loss: 0.0792 - accuracy: 0.9701 - val_loss: 0.0818 - val_accuracy: 0.9688
# Epoch 59/180
# F1 Macro Score: 0.94003
# 1000/1000 - 19s - loss: 0.0796 - accuracy: 0.9701 - val_loss: 0.0810 - val_accuracy: 0.9691
# Epoch 60/180
# F1 Macro Score: 0.94033
# 1000/1000 - 18s - loss: 0.0794 - accuracy: 0.9701 - val_loss: 0.0810 - val_accuracy: 0.9692
# Epoch 61/180
# F1 Macro Score: 0.94013
# 1000/1000 - 19s - loss: 0.0792 - accuracy: 0.9702 - val_loss: 0.0811 - val_accuracy: 0.9691
# Epoch 62/180
# F1 Macro Score: 0.94053
# 1000/1000 - 19s - loss: 0.0789 - accuracy: 0.9702 - val_loss: 0.0806 - val_accuracy: 0.9693
# Epoch 63/180
# F1 Macro Score: 0.93997
# 1000/1000 - 19s - loss: 0.0788 - accuracy: 0.9703 - val_loss: 0.0812 - val_accuracy: 0.9691
# Epoch 64/180
# F1 Macro Score: 0.94048
# 1000/1000 - 19s - loss: 0.0788 - accuracy: 0.9702 - val_loss: 0.0806 - val_accuracy: 0.9692
# Epoch 65/180
# F1 Macro Score: 0.94046
# 1000/1000 - 19s - loss: 0.0788 - accuracy: 0.9702 - val_loss: 0.0806 - val_accuracy: 0.9692
# Epoch 66/180
# F1 Macro Score: 0.94052
# 1000/1000 - 18s - loss: 0.0787 - accuracy: 0.9703 - val_loss: 0.0806 - val_accuracy: 0.9693
# Epoch 67/180
# F1 Macro Score: 0.94005
# 1000/1000 - 19s - loss: 0.0788 - accuracy: 0.9703 - val_loss: 0.0807 - val_accuracy: 0.9692
# Epoch 68/180
# F1 Macro Score: 0.94046
# 1000/1000 - 19s - loss: 0.0784 - accuracy: 0.9703 - val_loss: 0.0805 - val_accuracy: 0.9692
# Epoch 69/180
# F1 Macro Score: 0.94032
# 1000/1000 - 19s - loss: 0.0787 - accuracy: 0.9703 - val_loss: 0.0806 - val_accuracy: 0.9692
# Epoch 70/180
# F1 Macro Score: 0.94035
# 1000/1000 - 19s - loss: 0.0784 - accuracy: 0.9703 - val_loss: 0.0806 - val_accuracy: 0.9692
# Epoch 71/180
# F1 Macro Score: 0.94044
# 1000/1000 - 19s - loss: 0.0786 - accuracy: 0.9704 - val_loss: 0.0806 - val_accuracy: 0.9692
# Epoch 72/180
# F1 Macro Score: 0.94052
# 1000/1000 - 19s - loss: 0.0782 - accuracy: 0.9704 - val_loss: 0.0807 - val_accuracy: 0.9692
# Epoch 73/180
# F1 Macro Score: 0.94049
# 1000/1000 - 19s - loss: 0.0782 - accuracy: 0.9704 - val_loss: 0.0807 - val_accuracy: 0.9692
# Epoch 74/180
# F1 Macro Score: 0.94060
# 1000/1000 - 19s - loss: 0.0782 - accuracy: 0.9704 - val_loss: 0.0806 - val_accuracy: 0.9692
# Epoch 75/180
# F1 Macro Score: 0.94050
# 1000/1000 - 18s - loss: 0.0782 - accuracy: 0.9704 - val_loss: 0.0804 - val_accuracy: 0.9693
# Epoch 76/180
# F1 Macro Score: 0.93996
# 1000/1000 - 19s - loss: 0.0780 - accuracy: 0.9704 - val_loss: 0.0808 - val_accuracy: 0.9691
# Epoch 77/180
# F1 Macro Score: 0.94040
# 1000/1000 - 19s - loss: 0.0781 - accuracy: 0.9705 - val_loss: 0.0805 - val_accuracy: 0.9692
# Epoch 78/180
# F1 Macro Score: 0.94036
# 1000/1000 - 19s - loss: 0.0784 - accuracy: 0.9703 - val_loss: 0.0806 - val_accuracy: 0.9692
# Epoch 79/180
# F1 Macro Score: 0.94034
# 1000/1000 - 19s - loss: 0.0778 - accuracy: 0.9705 - val_loss: 0.0807 - val_accuracy: 0.9692
# Epoch 80/180
# F1 Macro Score: 0.94042
# 1000/1000 - 19s - loss: 0.0780 - accuracy: 0.9705 - val_loss: 0.0805 - val_accuracy: 0.9693
# Epoch 81/180
# F1 Macro Score: 0.94018
# 1000/1000 - 19s - loss: 0.0780 - accuracy: 0.9705 - val_loss: 0.0806 - val_accuracy: 0.9692
# Epoch 82/180
# F1 Macro Score: 0.94017
# 1000/1000 - 19s - loss: 0.0780 - accuracy: 0.9706 - val_loss: 0.0805 - val_accuracy: 0.9692
# Epoch 83/180
# F1 Macro Score: 0.94067
# 1000/1000 - 19s - loss: 0.0779 - accuracy: 0.9705 - val_loss: 0.0807 - val_accuracy: 0.9693
# Epoch 84/180
# F1 Macro Score: 0.94061
# 1000/1000 - 19s - loss: 0.0777 - accuracy: 0.9705 - val_loss: 0.0805 - val_accuracy: 0.9693
# Epoch 85/180
# F1 Macro Score: 0.94058
# 1000/1000 - 19s - loss: 0.0777 - accuracy: 0.9705 - val_loss: 0.0804 - val_accuracy: 0.9693
# Epoch 86/180
# F1 Macro Score: 0.94046
# 1000/1000 - 19s - loss: 0.0777 - accuracy: 0.9705 - val_loss: 0.0803 - val_accuracy: 0.9692
# Epoch 87/180
# F1 Macro Score: 0.94011
# 1000/1000 - 19s - loss: 0.0777 - accuracy: 0.9706 - val_loss: 0.0803 - val_accuracy: 0.9693
# Epoch 88/180
# F1 Macro Score: 0.94053
# 1000/1000 - 19s - loss: 0.0776 - accuracy: 0.9705 - val_loss: 0.0802 - val_accuracy: 0.9693
# Epoch 89/180
# F1 Macro Score: 0.94042
# 1000/1000 - 18s - loss: 0.0774 - accuracy: 0.9706 - val_loss: 0.0802 - val_accuracy: 0.9693
# Epoch 90/180
# F1 Macro Score: 0.94063
# 1000/1000 - 19s - loss: 0.0773 - accuracy: 0.9706 - val_loss: 0.0803 - val_accuracy: 0.9693
# Epoch 91/180
# F1 Macro Score: 0.94057
# 1000/1000 - 18s - loss: 0.0771 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9694
# Epoch 92/180
# F1 Macro Score: 0.94053
# 1000/1000 - 19s - loss: 0.0770 - accuracy: 0.9706 - val_loss: 0.0801 - val_accuracy: 0.9694
# Epoch 93/180
# F1 Macro Score: 0.94073
# 1000/1000 - 19s - loss: 0.0770 - accuracy: 0.9708 - val_loss: 0.0801 - val_accuracy: 0.9694
# Epoch 94/180
# F1 Macro Score: 0.94051
# 1000/1000 - 19s - loss: 0.0772 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 95/180
# F1 Macro Score: 0.94077
# 1000/1000 - 19s - loss: 0.0774 - accuracy: 0.9706 - val_loss: 0.0802 - val_accuracy: 0.9694
# Epoch 96/180
# F1 Macro Score: 0.94073
# 1000/1000 - 19s - loss: 0.0770 - accuracy: 0.9707 - val_loss: 0.0802 - val_accuracy: 0.9693
# Epoch 97/180
# F1 Macro Score: 0.94054
# 1000/1000 - 19s - loss: 0.0772 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 98/180
# F1 Macro Score: 0.94045
# 1000/1000 - 19s - loss: 0.0773 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 99/180
# F1 Macro Score: 0.94079
# 1000/1000 - 18s - loss: 0.0769 - accuracy: 0.9708 - val_loss: 0.0801 - val_accuracy: 0.9694
# Epoch 100/180
# F1 Macro Score: 0.94078
# 1000/1000 - 19s - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9694
# Epoch 101/180
# F1 Macro Score: 0.94050
# 1000/1000 - 18s - loss: 0.0770 - accuracy: 0.9708 - val_loss: 0.0802 - val_accuracy: 0.9693
# Epoch 102/180
# F1 Macro Score: 0.94044
# 1000/1000 - 19s - loss: 0.0770 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 103/180
# F1 Macro Score: 0.94045
# 1000/1000 - 19s - loss: 0.0770 - accuracy: 0.9707 - val_loss: 0.0802 - val_accuracy: 0.9693
# Epoch 104/180
# F1 Macro Score: 0.94048
# 1000/1000 - 19s - loss: 0.0770 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 105/180
# F1 Macro Score: 0.94070
# 1000/1000 - 19s - loss: 0.0770 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 106/180
# F1 Macro Score: 0.94060
# 1000/1000 - 19s - loss: 0.0771 - accuracy: 0.9706 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 107/180
# F1 Macro Score: 0.94049
# 1000/1000 - 19s - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 108/180
# F1 Macro Score: 0.94049
# 1000/1000 - 19s - loss: 0.0768 - accuracy: 0.9708 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 109/180
# F1 Macro Score: 0.94053
# 1000/1000 - 19s - loss: 0.0770 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9694
# Epoch 110/180
# F1 Macro Score: 0.94075
# 1000/1000 - 18s - loss: 0.0770 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9694
# Epoch 111/180
# F1 Macro Score: 0.94038
# 1000/1000 - 19s - loss: 0.0768 - accuracy: 0.9708 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 112/180
# F1 Macro Score: 0.94065
# 1000/1000 - 19s - loss: 0.0771 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9694
# Epoch 113/180
# F1 Macro Score: 0.94046
# 1000/1000 - 19s - loss: 0.0775 - accuracy: 0.9706 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 114/180
# F1 Macro Score: 0.94064
# 1000/1000 - 19s - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 115/180
# F1 Macro Score: 0.94062
# 1000/1000 - 19s - loss: 0.0772 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9694
# Epoch 116/180
# F1 Macro Score: 0.94047
# 1000/1000 - 19s - loss: 0.0768 - accuracy: 0.9708 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 117/180
# F1 Macro Score: 0.94049
# 1000/1000 - 19s - loss: 0.0768 - accuracy: 0.9708 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 118/180
# F1 Macro Score: 0.94057
# 1000/1000 - 19s - loss: 0.0770 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 119/180
# F1 Macro Score: 0.94057
# 1000/1000 - 19s - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 120/180
# F1 Macro Score: 0.94066
# 1000/1000 - 19s - loss: 0.0770 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9694
# Epoch 121/180
# F1 Macro Score: 0.94035
# 1000/1000 - 19s - loss: 0.0771 - accuracy: 0.9707 - val_loss: 0.0802 - val_accuracy: 0.9693
# Epoch 122/180
# F1 Macro Score: 0.94026
# 1000/1000 - 19s - loss: 0.0773 - accuracy: 0.9707 - val_loss: 0.0802 - val_accuracy: 0.9692
# Epoch 123/180
# F1 Macro Score: 0.94051
# 1000/1000 - 19s - loss: 0.0770 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 124/180
# F1 Macro Score: 0.94056
# 1000/1000 - 19s - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 125/180
# F1 Macro Score: 0.94046
# 1000/1000 - 19s - loss: 0.0770 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 126/180
# F1 Macro Score: 0.94060
# 1000/1000 - 19s - loss: 0.0771 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 127/180
# F1 Macro Score: 0.94059
# 1000/1000 - 19s - loss: 0.0773 - accuracy: 0.9708 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 128/180
# F1 Macro Score: 0.94043
# 1000/1000 - 18s - loss: 0.0769 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 129/180
# F1 Macro Score: 0.94035
# 1000/1000 - 19s - loss: 0.0770 - accuracy: 0.9707 - val_loss: 0.0802 - val_accuracy: 0.9693
# Epoch 130/180
# F1 Macro Score: 0.94052
# 1000/1000 - 19s - loss: 0.0766 - accuracy: 0.9708 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 131/180
# F1 Macro Score: 0.94075
# 1000/1000 - 19s - loss: 0.0771 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9694
# Epoch 132/180
# F1 Macro Score: 0.94071
# 1000/1000 - 19s - loss: 0.0767 - accuracy: 0.9708 - val_loss: 0.0801 - val_accuracy: 0.9694
# Epoch 133/180
# F1 Macro Score: 0.94059
# 1000/1000 - 18s - loss: 0.0767 - accuracy: 0.9708 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 134/180
# F1 Macro Score: 0.94061
# 1000/1000 - 19s - loss: 0.0768 - accuracy: 0.9708 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 135/180
# F1 Macro Score: 0.94034
# 1000/1000 - 19s - loss: 0.0767 - accuracy: 0.9708 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 136/180
# F1 Macro Score: 0.94064
# 1000/1000 - 19s - loss: 0.0771 - accuracy: 0.9707 - val_loss: 0.0801 - val_accuracy: 0.9693
# Epoch 137/180
