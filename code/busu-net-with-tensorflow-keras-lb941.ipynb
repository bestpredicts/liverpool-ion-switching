# %% [markdown]
# # Introduction & Acknowledgements
#
# - Built-upon:
#     - https://www.kaggle.com/kmat2019/u-net-1d-cnn-with-keras
#     - https://www.kaggle.com/nxrprime/wavenet-with-shifted-rfc-proba-and-cbr
#     - https://www.kaggle.com/khoongweihao/ion-switching-uuu-net-ladder-net-s-unet-idea/
# - Actually like Ladder-net (https://arxiv.org/abs/1810.07810) and S-unet (https://ieeexplore.ieee.org/abstract/document/8842560)
# - A similar implementation with bi-directional LSTMs in BUSU-Net, and my paper can be found at: https://arxiv.org/abs/2003.01581
# - Modified to a chain of U-Nets with diminishing depths
# - Thanks to https://www.kaggle.com/siavrez/wavenet-keras and Sergey Bryansky.
# - You can take a look at Sergey's kernel [here](https://www.kaggle.com/sggpls/shifted-rfc-pipeline) or [here](https://www.kaggle.com/sggpls/wavenet-with-shifted-rfc-proba). Also, Sergey's [data is here.](https://www.kaggle.com/sggpls/ion-shifted-rfc-proba)

# %% [markdown]
# # Imports

# %%
# !pip install tensorflow_addons
import tensorflow as tf
from tensorflow.keras.layers import *
import pandas as pd
import numpy as np
import random
from tensorflow.keras.callbacks import Callback, LearningRateScheduler
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras import losses, models, optimizers
import tensorflow_addons as tfa
import gc

from sklearn.model_selection import GroupKFold
from sklearn.metrics import f1_score

import warnings
warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 500)

import os
os.environ['CUDA_VISIBLE_DEVICES'] = '3'

for dirname, _, filenames in os.walk('../input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# Looking in indexes: https://pypi.doubanio.com/simple
# Requirement already satisfied: tensorflow_addons in /home/dy/anaconda3/lib/python3.7/site-packages (0.8.3)
# Requirement already satisfied: typeguard in /home/dy/anaconda3/lib/python3.7/site-packages (from tensorflow_addons) (2.7.1)
# WARNING: You are using pip version 20.1; however, version 20.1.1 is available.
# You should consider upgrading via the '/home/dy/anaconda3/bin/python -m pip install --upgrade pip' command.
# ../input/data-without-drift.zip
# ../input/Y_test_proba.npy
# ../input/train_clean_kalman.csv.zip
# ../input/train_clean.csv
# ../input/train_clean_kalman.csv
# ../input/test_clean.csv
# ../input/Y_train_proba.npy.zip
# ../input/test_clean_kalman.csv.zip
# ../input/test_clean_kalman.csv
# ../input/liverpool-ion-switching.zip
# ../input/sample_submission.csv
# ../input/Y_train_proba.npy
# ../input/train.csv
# ../input/test.csv
# ../input/Y_test_proba.npy.zip

# %%
# configurations and main hyperparammeters
EPOCHS = 120 # originally 180
NNBATCHSIZE = 16
GROUP_BATCH_SIZE = 4000
SEED = 42 # originally 321
LR = 0.001
SPLITS = 5

def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)

# %% [markdown]
# # Preprocessing Functions

# %%
# read data
def read_data():
    train = pd.read_csv('../input/train_clean.csv', dtype={'time': np.float32, 'signal': np.float32, 'open_channels':np.int32})
    test  = pd.read_csv('../input/test_clean.csv', dtype={'time': np.float32, 'signal': np.float32})
    sub  = pd.read_csv('../input/sample_submission.csv', dtype={'time': np.float32})
    
    Y_train_proba = np.load("../input/Y_train_proba.npy")
    Y_test_proba = np.load("../input/Y_test_proba.npy")
    
    for i in range(11):
        train[f"proba_{i}"] = Y_train_proba[:, i]
        test[f"proba_{i}"] = Y_test_proba[:, i]

    return train, test, sub

# create batches of 4000 observations
def batching(df, batch_size):
    df['group'] = df.groupby(df.index//batch_size, sort=False)['signal'].agg(['ngroup']).values
    df['group'] = df['group'].astype(np.uint16)
    return df

# normalize the data (standard scaler). We can also try other scalers for a better score!
def normalize(train, test):
    train_input_mean = train.signal.mean()
    train_input_sigma = train.signal.std()
    train['signal'] = (train.signal - train_input_mean) / train_input_sigma
    test['signal'] = (test.signal - train_input_mean) / train_input_sigma
    return train, test

# get lead and lags features
def lag_with_pct_change(df, windows):
    for window in windows:    
        df['signal_shift_pos_' + str(window)] = df.groupby('group')['signal'].shift(window).fillna(0)
        df['signal_shift_neg_' + str(window)] = df.groupby('group')['signal'].shift(-1 * window).fillna(0)
    return df

# main module to run feature engineering. Here you may want to try and add other features and check if your score imporves :).
def run_feat_engineering(df, batch_size):
    # create batches
    df = batching(df, batch_size = batch_size)
    # create leads and lags (1, 2, 3 making them 6 features)
    df = lag_with_pct_change(df, [1, 2, 3])
    # create signal ** 2 (this is the new feature)
    df['signal_2'] = df['signal'] ** 2
    return df

# fillna with the mean and select features for training
def feature_selection(train, test):
    features = [col for col in train.columns if col not in ['index', 'group', 'open_channels', 'time']]
    train = train.replace([np.inf, -np.inf], np.nan)
    test = test.replace([np.inf, -np.inf], np.nan)
    for feature in features:
        feature_mean = pd.concat([train[feature], test[feature]], axis = 0).mean()
        train[feature] = train[feature].fillna(feature_mean)
        test[feature] = test[feature].fillna(feature_mean)
    return train, test, features

# %% [markdown]
# # Model - BUSU-Net

# %%
def cbr(x, out_layer, kernel, stride, dilation):
    x = Conv1D(out_layer, kernel_size=kernel, dilation_rate=dilation, strides=stride, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

def se_block(x_in, layer_n):
    x = GlobalAveragePooling1D()(x_in)
    x = Dense(layer_n//8, activation="relu")(x)
    x = Dense(layer_n, activation="sigmoid")(x)
    x_out=Multiply()([x_in, x])
    return x_out

def resblock(x_in, layer_n, kernel, dilation, use_se=True):
    x = cbr(x_in, layer_n, kernel, 1, dilation)
    x = cbr(x, layer_n, kernel, 1, dilation)
    if use_se:
        x = se_block(x, layer_n)
    x = Add()([x_in, x])
    return x

# %%
def BUSUnet(input_shape=(None,1)):
    layer_n = 64
    kernel_size = 7
    depth = 2

    input_layer = Input(input_shape)    
    input_layer_1 = AveragePooling1D(5)(input_layer)
    input_layer_2 = AveragePooling1D(25)(input_layer)
    
    ##########################
    ### First U-Net: Big-U ###
    ##########################
    
    ########## Encoder 1
    x = cbr(input_layer, layer_n, kernel_size, 1, 1)
    for i in range(depth):
        x = resblock(x, layer_n, kernel_size, 1)
    out_0 = x

    x = cbr(x, layer_n*2, kernel_size, 5, 1)
    for i in range(depth):
        x = resblock(x, layer_n*2, kernel_size, 1)
    out_1 = x

    x = Concatenate()([x, input_layer_1])    
    x = cbr(x, layer_n*3, kernel_size, 5, 1)
    for i in range(depth):
        x = resblock(x, layer_n*3, kernel_size, 1)
    out_2 = x

    x = Concatenate()([x, input_layer_2])    
    x = cbr(x, layer_n*4, kernel_size, 5, 1)
    for i in range(depth):
        x = resblock(x, layer_n*4, kernel_size, 1)
    
    ########### Decoder 1
    x = UpSampling1D(5)(x)
    x = Concatenate()([x, out_2])
    x = cbr(x, layer_n*3, kernel_size, 1, 1)

    x = UpSampling1D(5)(x)
    x = Concatenate()([x, out_1])
    x = cbr(x, layer_n*2, kernel_size, 1, 1)

    x = UpSampling1D(5)(x)
    x = Concatenate()([x, out_0])
    x = cbr(x, layer_n, kernel_size, 1, 1)   
    
    #############################
    ### Second U-Net: Small-U ###
    #############################
    
    ########## Encoder 2
    for i in range(depth):
        x = resblock(x, layer_n, kernel_size, 1)
    out_0 = x

    x = cbr(x, layer_n*2, kernel_size, 5, 1)
    for i in range(depth):
        x = resblock(x, layer_n*2, kernel_size, 1)
    out_1 = x

    x = Concatenate()([x, input_layer_1])    
    x = cbr(x, layer_n*3, kernel_size, 5, 1)
    for i in range(depth):
        x = resblock(x, layer_n*3, kernel_size, 1)
    
    ########### Decoder 2
    x = UpSampling1D(5)(x)
    x = Concatenate()([x, out_1])
    x = cbr(x, layer_n*2, kernel_size, 1, 1)

    x = UpSampling1D(5)(x)
    x = Concatenate()([x, out_0])
    x = cbr(x, layer_n, kernel_size, 1, 1) 
    
    #classifier
    x = Conv1D(11, kernel_size=kernel_size, strides=1, padding="same")(x)
    out = Activation("softmax")(x)
    
    model = models.Model(inputs = input_layer, outputs = out)
    
    opt = Adam(lr = LR)
    opt = tfa.optimizers.SWA(opt)
    model.compile(loss = losses.CategoricalCrossentropy(), optimizer = opt, metrics = ['accuracy'])
    return model

# %% [markdown]
# # Training Functions

# %%
# function that decrease the learning as epochs increase (i also change this part of the code)
def lr_schedule(epoch):
    if epoch < 30:
        lr = LR
    elif epoch < 40:
        lr = LR / 3
    elif epoch < 50:
        lr = LR / 5
    elif epoch < 60:
        lr = LR / 7
    elif epoch < 70:
        lr = LR / 9
    elif epoch < 80:
        lr = LR / 11
    elif epoch < 90:
        lr = LR / 13
    elif epoch < 100:
        lr = LR / 15
    else:
        lr = LR / 100
    return lr

# class to get macro f1 score. This is not entirely necessary but it's fun to check f1 score of each epoch (be carefull, if you use this function early stopping callback will not work)
class MacroF1(Callback):
    def __init__(self, model, inputs, targets):
        self.model = model
        self.inputs = inputs
        self.targets = np.argmax(targets, axis = 2).reshape(-1)
        
    def on_epoch_end(self, epoch, logs):
        pred = np.argmax(self.model.predict(self.inputs), axis = 2).reshape(-1)
        score = f1_score(self.targets, pred, average = 'macro')
        print(f'F1 Macro Score: {score:.5f}')

# main function to perfrom groupkfold cross validation (we have 1000 vectores of 4000 rows and 8 features (columns)). Going to make 5 groups with this subgroups.
def run_cv_model_by_batch(train, test, splits, batch_col, feats, sample_submission, nn_epochs, nn_batch_size):
    
    seed_everything(SEED)
    K.clear_session()
    config = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1,inter_op_parallelism_threads=1)
    sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=config)
    tf.compat.v1.keras.backend.set_session(sess)
    oof_ = np.zeros((len(train), 11)) # build out of folds matrix with 11 columns, they represent our target variables classes (from 0 to 10)
    preds_ = np.zeros((len(test), 11))
    target = ['open_channels']
    group = train['group']
    kf = GroupKFold(n_splits=5)
    splits = [x for x in kf.split(train, train[target], group)]

    new_splits = []
    for sp in splits:
        new_split = []
        new_split.append(np.unique(group[sp[0]]))
        new_split.append(np.unique(group[sp[1]]))
        new_split.append(sp[1])    
        new_splits.append(new_split)
    # pivot target columns to transform the net to a multiclass classification estructure (you can also leave it in 1 vector with sparsecategoricalcrossentropy loss function)
    tr = pd.concat([pd.get_dummies(train.open_channels), train[['group']]], axis=1)

    tr.columns = ['target_'+str(i) for i in range(11)] + ['group']
    target_cols = ['target_'+str(i) for i in range(11)]
    train_tr = np.array(list(tr.groupby('group').apply(lambda x: x[target_cols].values))).astype(np.float32)
    train = np.array(list(train.groupby('group').apply(lambda x: x[feats].values)))
    test = np.array(list(test.groupby('group').apply(lambda x: x[feats].values)))

    for n_fold, (tr_idx, val_idx, val_orig_idx) in enumerate(new_splits[0:], start=0):
        train_x, train_y = train[tr_idx], train_tr[tr_idx]
        valid_x, valid_y = train[val_idx], train_tr[val_idx]
        print(f'Our training dataset shape is {train_x.shape}')
        print(f'Our validation dataset shape is {valid_x.shape}')

        gc.collect()
        shape_ = (None, train_x.shape[2]) # input is going to be the number of feature we are using (dimension 2 of 0, 1, 2)
        #model = Classifier(shape_)
        model = BUSUnet(shape_)
        # using our lr_schedule function
        cb_lr_schedule = LearningRateScheduler(lr_schedule)
        model.fit(train_x,train_y,
                  epochs = nn_epochs,
                  callbacks = [cb_lr_schedule, MacroF1(model, valid_x, valid_y)], # adding custom evaluation metric for each epoch
                  batch_size = nn_batch_size,verbose = 2,
                  validation_data = (valid_x,valid_y))
        preds_f = model.predict(valid_x)
        f1_score_ = f1_score(np.argmax(valid_y, axis=2).reshape(-1),  np.argmax(preds_f, axis=2).reshape(-1), average = 'macro') # need to get the class with the biggest probability
        print(f'Training fold {n_fold + 1} completed. macro f1 score : {f1_score_ :1.5f}')
        preds_f = preds_f.reshape(-1, preds_f.shape[-1])
        oof_[val_orig_idx,:] += preds_f
        te_preds = model.predict(test)
        te_preds = te_preds.reshape(-1, te_preds.shape[-1])           
        preds_ += te_preds / SPLITS
    # calculate the oof macro f1_score
    
    

    np.save("oof_train/oof_train_busu_lb941.npy",oof_)
    np.save("oof_test/oof_test_busu_lb941.npy",preds_)
    
    f1_score_ = f1_score(np.argmax(train_tr, axis = 2).reshape(-1),  np.argmax(oof_, axis = 1), average = 'macro') # axis 2 for the 3 Dimension array and axis 1 for the 2 Domension Array (extracting the best class)
    print(f'Training completed. oof macro f1 score : {f1_score_:1.5f}')
    sample_submission['open_channels'] = np.argmax(preds_, axis = 1).astype(int)
    sample_submission.to_csv('submission_BUSUnet.csv', index=False, float_format='%.4f')

# %% [markdown]
# # Training & Inference

# %%
# this function run our entire program
def run_everything():
    
    print('Reading Data Started...')
    train, test, sample_submission = read_data()
    train, test = normalize(train, test)
    print('Reading and Normalizing Data Completed')
        
    print('Creating Features')
    print('Feature Engineering Started...')
    train = run_feat_engineering(train, batch_size = GROUP_BATCH_SIZE)
    test = run_feat_engineering(test, batch_size = GROUP_BATCH_SIZE)
    train, test, features = feature_selection(train, test)
    print('Feature Engineering Completed...')
        
   
    print(f'Training BUSU-Net model with {SPLITS} folds of GroupKFold Started...')
    run_cv_model_by_batch(train, test, SPLITS, 'group', features, sample_submission, EPOCHS, NNBATCHSIZE)
    print('Training completed...')
        
run_everything()
# Out:
# Reading Data Started...
# Reading and Normalizing Data Completed
# Creating Features
# Feature Engineering Started...
# Feature Engineering Completed...
# Training BUSU-Net model with 5 folds of GroupKFold Started...
# Our training dataset shape is (1000, 4000, 19)
# Our validation dataset shape is (250, 4000, 19)
# Train on 1000 samples, validate on 250 samples
# Epoch 1/120
# WARNING:tensorflow:From /home/dy/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# F1 Macro Score: 0.47153
# 1000/1000 - 165s - loss: 0.6504 - accuracy: 0.7727 - val_loss: 2.2135 - val_accuracy: 0.7224
# Epoch 2/120
# F1 Macro Score: 0.69665
# 1000/1000 - 25s - loss: 0.1850 - accuracy: 0.9502 - val_loss: 0.6793 - val_accuracy: 0.8342
# Epoch 3/120
# F1 Macro Score: 0.92394
# 1000/1000 - 25s - loss: 0.1243 - accuracy: 0.9648 - val_loss: 0.2912 - val_accuracy: 0.9574
# Epoch 4/120
# F1 Macro Score: 0.93373
# 1000/1000 - 25s - loss: 0.1108 - accuracy: 0.9665 - val_loss: 0.1538 - val_accuracy: 0.9641
# Epoch 5/120
# F1 Macro Score: 0.93271
# 1000/1000 - 26s - loss: 0.1068 - accuracy: 0.9670 - val_loss: 0.1307 - val_accuracy: 0.9637
# Epoch 6/120
# F1 Macro Score: 0.93673
# 1000/1000 - 25s - loss: 0.1030 - accuracy: 0.9675 - val_loss: 0.1121 - val_accuracy: 0.9658
# Epoch 7/120
# F1 Macro Score: 0.93539
# 1000/1000 - 25s - loss: 0.0997 - accuracy: 0.9677 - val_loss: 0.1078 - val_accuracy: 0.9655
# Epoch 8/120
# F1 Macro Score: 0.79837
# 1000/1000 - 25s - loss: 0.1273 - accuracy: 0.9616 - val_loss: 0.4878 - val_accuracy: 0.8811
# Epoch 9/120
# F1 Macro Score: 0.78988
# 1000/1000 - 24s - loss: 0.1235 - accuracy: 0.9642 - val_loss: 3.3107 - val_accuracy: 0.7477
# Epoch 10/120
# F1 Macro Score: 0.92140
# 1000/1000 - 25s - loss: 0.1053 - accuracy: 0.9671 - val_loss: 0.1677 - val_accuracy: 0.9444
# Epoch 11/120
# F1 Macro Score: 0.93714
# 1000/1000 - 25s - loss: 0.0992 - accuracy: 0.9678 - val_loss: 0.1048 - val_accuracy: 0.9656
# Epoch 12/120
# F1 Macro Score: 0.93678
# F1 Macro Score: 0.93818
# 1000/1000 - 23s - loss: 0.0821 - accuracy: 0.9694 - val_loss: 0.0879 - val_accuracy: 0.9671
# Epoch 119/120
# F1 Macro Score: 0.93832
# 1000/1000 - 22s - loss: 0.0825 - accuracy: 0.9694 - val_loss: 0.0878 - val_accuracy: 0.9671
# Epoch 120/120
# F1 Macro Score: 0.93833
# 1000/1000 - 22s - loss: 0.0818 - accuracy: 0.9695 - val_loss: 0.0877 - val_accuracy: 0.9671
# Training fold 1 completed. macro f1 score : 0.93833
# Our training dataset shape is (1000, 4000, 19)
# Our validation dataset shape is (250, 4000, 19)
# Train on 1000 samples, validate on 250 samples
# Epoch 1/120
# F1 Macro Score: 0.40845
# 1000/1000 - 128s - loss: 0.6627 - accuracy: 0.7694 - val_loss: 1.9771 - val_accuracy: 0.6713
# Epoch 2/120
# F1 Macro Score: 0.44674
# 1000/1000 - 24s - loss: 0.2012 - accuracy: 0.9418 - val_loss: 0.8099 - val_accuracy: 0.7506
# Epoch 3/120
# F1 Macro Score: 0.58245
# 1000/1000 - 23s - loss: 0.1432 - accuracy: 0.9599 - val_loss: 0.6262 - val_accuracy: 0.7916
# Epoch 4/120
# F1 Macro Score: 0.41685
# 1000/1000 - 23s - loss: 0.1433 - accuracy: 0.9604 - val_loss: 2.5575 - val_accuracy: 0.6652
# Epoch 5/120
# F1 Macro Score: 0.46876
# 1000/1000 - 23s - loss: 0.1645 - accuracy: 0.9534 - val_loss: 2.6565 - val_accuracy: 0.7947
# Epoch 6/120
# F1 Macro Score: 0.64510
# 1000/1000 - 23s - loss: 0.1406 - accuracy: 0.9609 - val_loss: 0.5144 - val_accuracy: 0.8515
# Epoch 7/120
# F1 Macro Score: 0.93308
# 1000/1000 - 24s - loss: 0.1158 - accuracy: 0.9653 - val_loss: 0.1151 - val_accuracy: 0.9665
# Epoch 8/120
# F1 Macro Score: 0.93437
# 1000/1000 - 23s - loss: 0.1067 - accuracy: 0.9665 - val_loss: 0.1057 - val_accuracy: 0.9681
# Epoch 9/120
# F1 Macro Score: 0.93805
# 1000/1000 - 23s - loss: 0.1042 - accuracy: 0.9668 - val_loss: 0.0995 - val_accuracy: 0.9688
# Epoch 10/120
# F1 Macro Score: 0.93775
# 1000/1000 - 23s - loss: 0.1020 - accuracy: 0.9671 - val_loss: 0.0960 - val_accuracy: 0.9689
# Epoch 11/120
# F1 Macro Score: 0.93816
# 1000/1000 - 23s - loss: 0.1000 - accuracy: 0.9672 - val_loss: 0.0943 - val_accuracy: 0.9691
# Epoch 12/120
# F1 Macro Score: 0.93235
# 1000/1000 - 23s - loss: 0.0986 - accuracy: 0.9673 - val_loss: 0.1022 - val_accuracy: 0.9670
# Epoch 13/120
# F1 Macro Score: 0.58427
# 1000/1000 - 23s - loss: 0.1047 - accuracy: 0.9661 - val_loss: 7.0193 - val_accuracy: 0.4117
# Epoch 14/120
# F1 Macro Score: 0.92778
# 1000/1000 - 23s - loss: 0.1139 - accuracy: 0.9650 - val_loss: 0.1181 - val_accuracy: 0.9648
# Epoch 50/120
# F1 Macro Score: 0.93943
# 1000/1000 - 24s - loss: 0.0890 - accuracy: 0.9681 - val_loss: 0.0847 - val_accuracy: 0.9696
# Epoch 51/120
# F1 Macro Score: 0.93863
# 1000/1000 - 23s - loss: 0.0884 - accuracy: 0.9682 - val_loss: 0.0853 - val_accuracy: 0.9695
# Epoch 52/120
# F1 Macro Score: 0.93903
# 1000/1000 - 23s - loss: 0.0883 - accuracy: 0.9682 - val_loss: 0.0849 - val_accuracy: 0.9695
# Epoch 53/120
# F1 Macro Score: 0.93756
# 1000/1000 - 23s - loss: 0.0885 - accuracy: 0.9681 - val_loss: 0.0862 - val_accuracy: 0.9691
# Epoch 54/120
# F1 Macro Score: 0.93916
# 1000/1000 - 23s - loss: 0.0883 - accuracy: 0.9682 - val_loss: 0.0851 - val_accuracy: 0.9695
# Epoch 55/120
# F1 Macro Score: 0.93927
# 1000/1000 - 24s - loss: 0.0879 - accuracy: 0.9682 - val_loss: 0.0841 - val_accuracy: 0.9697
# Epoch 56/120
# F1 Macro Score: 0.93784
# 1000/1000 - 23s - loss: 0.0881 - accuracy: 0.9682 - val_loss: 0.0852 - val_accuracy: 0.9693
# Epoch 57/120
# F1 Macro Score: 0.93920
# 1000/1000 - 23s - loss: 0.0881 - accuracy: 0.9681 - val_loss: 0.0843 - val_accuracy: 0.9696
# Epoch 58/120
# F1 Macro Score: 0.93916
# 1000/1000 - 23s - loss: 0.0878 - accuracy: 0.9682 - val_loss: 0.0846 - val_accuracy: 0.9695
# Epoch 59/120
# F1 Macro Score: 0.93801
# 1000/1000 - 23s - loss: 0.0879 - accuracy: 0.9682 - val_loss: 0.0853 - val_accuracy: 0.9693
# Epoch 60/120
# F1 Macro Score: 0.93912
# 1000/1000 - 24s - loss: 0.0875 - accuracy: 0.9683 - val_loss: 0.0846 - val_accuracy: 0.9695
# Epoch 61/120
# F1 Macro Score: 0.93929
# 1000/1000 - 24s - loss: 0.0870 - accuracy: 0.9683 - val_loss: 0.0837 - val_accuracy: 0.9697
# Epoch 62/120
# F1 Macro Score: 0.93941
# 1000/1000 - 23s - loss: 0.0870 - accuracy: 0.9683 - val_loss: 0.0837 - val_accuracy: 0.9697
# Epoch 63/120
# F1 Macro Score: 0.93933
# 1000/1000 - 23s - loss: 0.0865 - accuracy: 0.9684 - val_loss: 0.0838 - val_accuracy: 0.9697
# Epoch 64/120
# F1 Macro Score: 0.93929
# 1000/1000 - 23s - loss: 0.0868 - accuracy: 0.9683 - val_loss: 0.0838 - val_accuracy: 0.9697
# Epoch 65/120
# F1 Macro Score: 0.93911
# 1000/1000 - 22s - loss: 0.0864 - accuracy: 0.9684 - val_loss: 0.0839 - val_accuracy: 0.9696
# Epoch 66/120
# F1 Macro Score: 0.93782
# 1000/1000 - 24s - loss: 0.0864 - accuracy: 0.9684 - val_loss: 0.0848 - val_accuracy: 0.9692
# Epoch 67/120
# F1 Macro Score: 0.93907
# 1000/1000 - 25s - loss: 0.0863 - accuracy: 0.9684 - val_loss: 0.0835 - val_accuracy: 0.9696
# Epoch 68/120
# F1 Macro Score: 0.93897
# 1000/1000 - 23s - loss: 0.0868 - accuracy: 0.9684 - val_loss: 0.0835 - val_accuracy: 0.9696
# Epoch 69/120
# F1 Macro Score: 0.93863
# 1000/1000 - 23s - loss: 0.0877 - accuracy: 0.9681 - val_loss: 0.0853 - val_accuracy: 0.9693
# Epoch 70/120
# F1 Macro Score: 0.93890
# 1000/1000 - 23s - loss: 0.0877 - accuracy: 0.9681 - val_loss: 0.0845 - val_accuracy: 0.9695
# Epoch 71/120
# F1 Macro Score: 0.93904
# 1000/1000 - 23s - loss: 0.0864 - accuracy: 0.9684 - val_loss: 0.0836 - val_accuracy: 0.9696
# Epoch 72/120
# F1 Macro Score: 0.93914
# 1000/1000 - 23s - loss: 0.0859 - accuracy: 0.9685 - val_loss: 0.0834 - val_accuracy: 0.9697
# Epoch 73/120
# F1 Macro Score: 0.93919
# 1000/1000 - 23s - loss: 0.0857 - accuracy: 0.9685 - val_loss: 0.0832 - val_accuracy: 0.9696
# Epoch 74/120
# F1 Macro Score: 0.93934
# 1000/1000 - 23s - loss: 0.0853 - accuracy: 0.9685 - val_loss: 0.0830 - val_accuracy: 0.9697
# Epoch 75/120
# F1 Macro Score: 0.93935
# 1000/1000 - 23s - loss: 0.0854 - accuracy: 0.9686 - val_loss: 0.0828 - val_accuracy: 0.9697
# Epoch 76/120
# F1 Macro Score: 0.93944
# 1000/1000 - 23s - loss: 0.0856 - accuracy: 0.9685 - val_loss: 0.0830 - val_accuracy: 0.9697
# Epoch 77/120
# F1 Macro Score: 0.93921
# 1000/1000 - 23s - loss: 0.0849 - accuracy: 0.9686 - val_loss: 0.0833 - val_accuracy: 0.9696
# Epoch 78/120
# F1 Macro Score: 0.93951
# 1000/1000 - 23s - loss: 0.0851 - accuracy: 0.9686 - val_loss: 0.0826 - val_accuracy: 0.9697
# Epoch 79/120
# F1 Macro Score: 0.93941
# 1000/1000 - 23s - loss: 0.0851 - accuracy: 0.9686 - val_loss: 0.0826 - val_accuracy: 0.9697
# Epoch 80/120
# F1 Macro Score: 0.93935
# 1000/1000 - 23s - loss: 0.0848 - accuracy: 0.9686 - val_loss: 0.0827 - val_accuracy: 0.9697
# Epoch 81/120
# F1 Macro Score: 0.93935
# 1000/1000 - 23s - loss: 0.0842 - accuracy: 0.9688 - val_loss: 0.0827 - val_accuracy: 0.9697
# Epoch 82/120
# F1 Macro Score: 0.93891
# 1000/1000 - 23s - loss: 0.0848 - accuracy: 0.9686 - val_loss: 0.0829 - val_accuracy: 0.9696
# Epoch 83/120
# F1 Macro Score: 0.93885
# 1000/1000 - 24s - loss: 0.0845 - accuracy: 0.9687 - val_loss: 0.0830 - val_accuracy: 0.9696
# Epoch 84/120
# F1 Macro Score: 0.93903
# 1000/1000 - 23s - loss: 0.0845 - accuracy: 0.9687 - val_loss: 0.0830 - val_accuracy: 0.9696
# Epoch 85/120
# F1 Macro Score: 0.93949
# 1000/1000 - 24s - loss: 0.0837 - accuracy: 0.9689 - val_loss: 0.0826 - val_accuracy: 0.9698
# Epoch 86/120
# F1 Macro Score: 0.93843
# 1000/1000 - 24s - loss: 0.0837 - accuracy: 0.9689 - val_loss: 0.0830 - val_accuracy: 0.9695
# Epoch 87/120
# F1 Macro Score: 0.93892
# 1000/1000 - 24s - loss: 0.0843 - accuracy: 0.9688 - val_loss: 0.0827 - val_accuracy: 0.9695
# Epoch 88/120
# F1 Macro Score: 0.93907
# 1000/1000 - 23s - loss: 0.0840 - accuracy: 0.9689 - val_loss: 0.0826 - val_accuracy: 0.9696
# Epoch 89/120
# F1 Macro Score: 0.93943
# 1000/1000 - 23s - loss: 0.0837 - accuracy: 0.9689 - val_loss: 0.0822 - val_accuracy: 0.9698
# Epoch 90/120
# F1 Macro Score: 0.93878
# 1000/1000 - 23s - loss: 0.0830 - accuracy: 0.9690 - val_loss: 0.0821 - val_accuracy: 0.9697
# Epoch 91/120
# F1 Macro Score: 0.93919
# 1000/1000 - 23s - loss: 0.0828 - accuracy: 0.9691 - val_loss: 0.0822 - val_accuracy: 0.9697
# Epoch 92/120
# F1 Macro Score: 0.93883
# 1000/1000 - 24s - loss: 0.0827 - accuracy: 0.9691 - val_loss: 0.0822 - val_accuracy: 0.9697
# Epoch 93/120
# F1 Macro Score: 0.93955
# 1000/1000 - 23s - loss: 0.0827 - accuracy: 0.9692 - val_loss: 0.0821 - val_accuracy: 0.9698
# Epoch 94/120
# F1 Macro Score: 0.93908
# 1000/1000 - 23s - loss: 0.0825 - accuracy: 0.9692 - val_loss: 0.0823 - val_accuracy: 0.9696
# Epoch 95/120
# F1 Macro Score: 0.93911
# 1000/1000 - 24s - loss: 0.0825 - accuracy: 0.9692 - val_loss: 0.0824 - val_accuracy: 0.9697
# Epoch 96/120
# F1 Macro Score: 0.93947
# 1000/1000 - 24s - loss: 0.0820 - accuracy: 0.9693 - val_loss: 0.0821 - val_accuracy: 0.9698
# Epoch 97/120
# F1 Macro Score: 0.93949
# 1000/1000 - 23s - loss: 0.0816 - accuracy: 0.9694 - val_loss: 0.0818 - val_accuracy: 0.9698
# Epoch 98/120
# F1 Macro Score: 0.93848
# 1000/1000 - 23s - loss: 0.0815 - accuracy: 0.9695 - val_loss: 0.0827 - val_accuracy: 0.9695
# Epoch 99/120
# F1 Macro Score: 0.93947
# 1000/1000 - 23s - loss: 0.0814 - accuracy: 0.9695 - val_loss: 0.0819 - val_accuracy: 0.9699
# Epoch 100/120
# F1 Macro Score: 0.93939
# 1000/1000 - 22s - loss: 0.0814 - accuracy: 0.9695 - val_loss: 0.0820 - val_accuracy: 0.9698
# Epoch 101/120
# F1 Macro Score: 0.93943
# 1000/1000 - 23s - loss: 0.0803 - accuracy: 0.9698 - val_loss: 0.0816 - val_accuracy: 0.9699
# Epoch 102/120
# F1 Macro Score: 0.93929
# 1000/1000 - 23s - loss: 0.0802 - accuracy: 0.9699 - val_loss: 0.0817 - val_accuracy: 0.9698
# Epoch 103/120
# F1 Macro Score: 0.93928
# 1000/1000 - 23s - loss: 0.0804 - accuracy: 0.9698 - val_loss: 0.0817 - val_accuracy: 0.9698
# Epoch 104/120
# F1 Macro Score: 0.93951
# 1000/1000 - 23s - loss: 0.0801 - accuracy: 0.9699 - val_loss: 0.0818 - val_accuracy: 0.9699
# Epoch 105/120
# F1 Macro Score: 0.93949
# 1000/1000 - 24s - loss: 0.0798 - accuracy: 0.9700 - val_loss: 0.0818 - val_accuracy: 0.9698
# Epoch 106/120
# F1 Macro Score: 0.93952
# 1000/1000 - 24s - loss: 0.0802 - accuracy: 0.9699 - val_loss: 0.0818 - val_accuracy: 0.9698
# Epoch 107/120
# F1 Macro Score: 0.93938
# 1000/1000 - 23s - loss: 0.0796 - accuracy: 0.9700 - val_loss: 0.0819 - val_accuracy: 0.9698
# Epoch 108/120
# F1 Macro Score: 0.93938
# 1000/1000 - 24s - loss: 0.0796 - accuracy: 0.9700 - val_loss: 0.0820 - val_accuracy: 0.9698
# Epoch 109/120
# F1 Macro Score: 0.93894
# 1000/1000 - 23s - loss: 0.0795 - accuracy: 0.9701 - val_loss: 0.0821 - val_accuracy: 0.9697
# Epoch 110/120
# F1 Macro Score: 0.93930
# 1000/1000 - 23s - loss: 0.0798 - accuracy: 0.9700 - val_loss: 0.0820 - val_accuracy: 0.9698
# Epoch 111/120
# F1 Macro Score: 0.93918
# 1000/1000 - 21s - loss: 0.0795 - accuracy: 0.9701 - val_loss: 0.0820 - val_accuracy: 0.9698
# Epoch 112/120
# F1 Macro Score: 0.93911
# 1000/1000 - 24s - loss: 0.0794 - accuracy: 0.9701 - val_loss: 0.0822 - val_accuracy: 0.9697
# Epoch 113/120
# F1 Macro Score: 0.93920
# 1000/1000 - 20s - loss: 0.0790 - accuracy: 0.9702 - val_loss: 0.0821 - val_accuracy: 0.9697
# Epoch 114/120
# F1 Macro Score: 0.93882
# 1000/1000 - 21s - loss: 0.0792 - accuracy: 0.9702 - val_loss: 0.0822 - val_accuracy: 0.9696
# Epoch 115/120
# F1 Macro Score: 0.93916
# 1000/1000 - 22s - loss: 0.0787 - accuracy: 0.9704 - val_loss: 0.0821 - val_accuracy: 0.9698
# Epoch 116/120
# F1 Macro Score: 0.93893
# 1000/1000 - 23s - loss: 0.0794 - accuracy: 0.9702 - val_loss: 0.0823 - val_accuracy: 0.9697
# Epoch 117/120
# F1 Macro Score: 0.93919
# 1000/1000 - 23s - loss: 0.0787 - accuracy: 0.9704 - val_loss: 0.0823 - val_accuracy: 0.9697
# Epoch 118/120
# F1 Macro Score: 0.93875
# 1000/1000 - 23s - loss: 0.0790 - accuracy: 0.9703 - val_loss: 0.0824 - val_accuracy: 0.9697
# Epoch 119/120
# F1 Macro Score: 0.93907
# 1000/1000 - 23s - loss: 0.0792 - accuracy: 0.9703 - val_loss: 0.0823 - val_accuracy: 0.9697
# Epoch 120/120
# F1 Macro Score: 0.93895
# 1000/1000 - 24s - loss: 0.0784 - accuracy: 0.9704 - val_loss: 0.0824 - val_accuracy: 0.9697
# Training fold 2 completed. macro f1 score : 0.93895
# Our training dataset shape is (1000, 4000, 19)
# Our validation dataset shape is (250, 4000, 19)
# Train on 1000 samples, validate on 250 samples
# Epoch 1/120
# F1 Macro Score: 0.51110
# 1000/1000 - 125s - loss: 0.6803 - accuracy: 0.7650 - val_loss: 1.0970 - val_accuracy: 0.7988
# Epoch 2/120
# F1 Macro Score: 0.65844
# 1000/1000 - 23s - loss: 0.2389 - accuracy: 0.9283 - val_loss: 0.5715 - val_accuracy: 0.8588
# Epoch 3/120
# F1 Macro Score: 0.63664
# 1000/1000 - 24s - loss: 0.1748 - accuracy: 0.9523 - val_loss: 0.5000 - val_accuracy: 0.8335
# Epoch 4/120
# F1 Macro Score: 0.88792
# 1000/1000 - 24s - loss: 0.1330 - accuracy: 0.9622 - val_loss: 0.1961 - val_accuracy: 0.9507
# Epoch 5/120
# F1 Macro Score: 0.92986
# 1000/1000 - 23s - loss: 0.1173 - accuracy: 0.9651 - val_loss: 0.1253 - val_accuracy: 0.9652
# Epoch 6/120
# F1 Macro Score: 0.93355
# 1000/1000 - 24s - loss: 0.1112 - accuracy: 0.9660 - val_loss: 0.1149 - val_accuracy: 0.9661
# Epoch 7/120
# F1 Macro Score: 0.93525
# 1000/1000 - 23s - loss: 0.1042 - accuracy: 0.9668 - val_loss: 0.1020 - val_accuracy: 0.9674
# Epoch 8/120
# F1 Macro Score: 0.93535
# 1000/1000 - 24s - loss: 0.1020 - accuracy: 0.9670 - val_loss: 0.1010 - val_accuracy: 0.9675
# Epoch 9/120
# F1 Macro Score: 0.93457
# 1000/1000 - 23s - loss: 0.0998 - accuracy: 0.9673 - val_loss: 0.1034 - val_accuracy: 0.9669
# Epoch 10/120
# F1 Macro Score: 0.93458
# 1000/1000 - 23s - loss: 0.1000 - accuracy: 0.9671 - val_loss: 0.1009 - val_accuracy: 0.9671
# Epoch 11/120
# F1 Macro Score: 0.93375
# 1000/1000 - 23s - loss: 0.0980 - accuracy: 0.9674 - val_loss: 0.1011 - val_accuracy: 0.9668
# Epoch 12/120
# F1 Macro Score: 0.93644
# 1000/1000 - 23s - loss: 0.0963 - accuracy: 0.9677 - val_loss: 0.0939 - val_accuracy: 0.9680
# Epoch 13/120
# F1 Macro Score: 0.93464
# 1000/1000 - 23s - loss: 0.0956 - accuracy: 0.9677 - val_loss: 0.0973 - val_accuracy: 0.9674
# Epoch 14/120
# F1 Macro Score: 0.92666
# 1000/1000 - 23s - loss: 0.0939 - accuracy: 0.9679 - val_loss: 0.1007 - val_accuracy: 0.9664
# Epoch 15/120
# F1 Macro Score: 0.93509
# 1000/1000 - 23s - loss: 0.0948 - accuracy: 0.9676 - val_loss: 0.0974 - val_accuracy: 0.9673
# Epoch 16/120
# F1 Macro Score: 0.93620
# 1000/1000 - 23s - loss: 0.0959 - accuracy: 0.9675 - val_loss: 0.0940 - val_accuracy: 0.9681
# Epoch 17/120
# F1 Macro Score: 0.93655
# 1000/1000 - 23s - loss: 0.0930 - accuracy: 0.9678 - val_loss: 0.0920 - val_accuracy: 0.9681
# Epoch 18/120
# F1 Macro Score: 0.27774
# 1000/1000 - 23s - loss: 0.1045 - accuracy: 0.9648 - val_loss: 4.1906 - val_accuracy: 0.4382
# Epoch 19/120
# F1 Macro Score: 0.35644
# 1000/1000 - 23s - loss: 0.2204 - accuracy: 0.9374 - val_loss: 5.6261 - val_accuracy: 0.5601
# Epoch 20/120
# F1 Macro Score: 0.62053
# 1000/1000 - 23s - loss: 0.1398 - accuracy: 0.9597 - val_loss: 1.8181 - val_accuracy: 0.6655
# Epoch 21/120
# F1 Macro Score: 0.93419
# 1000/1000 - 24s - loss: 0.1075 - accuracy: 0.9663 - val_loss: 0.1101 - val_accuracy: 0.9661
# Epoch 22/120
# F1 Macro Score: 0.93494
# 1000/1000 - 23s - loss: 0.1023 - accuracy: 0.9669 - val_loss: 0.1017 - val_accuracy: 0.9673
# Epoch 23/120
# F1 Macro Score: 0.93291
# 1000/1000 - 23s - loss: 0.1033 - accuracy: 0.9665 - val_loss: 0.1046 - val_accuracy: 0.9671
# Epoch 24/120
# F1 Macro Score: 0.42987
# 1000/1000 - 23s - loss: 0.1323 - accuracy: 0.9613 - val_loss: 2.2208 - val_accuracy: 0.5710
# Epoch 25/120
# F1 Macro Score: 0.93591
# 1000/1000 - 23s - loss: 0.1065 - accuracy: 0.9664 - val_loss: 0.1019 - val_accuracy: 0.9671
# Epoch 26/120
# F1 Macro Score: 0.93638
# 1000/1000 - 23s - loss: 0.0999 - accuracy: 0.9671 - val_loss: 0.0971 - val_accuracy: 0.9677
# Epoch 27/120
# F1 Macro Score: 0.93627
# 1000/1000 - 24s - loss: 0.0979 - accuracy: 0.9674 - val_loss: 0.0998 - val_accuracy: 0.9676
# Epoch 28/120
# F1 Macro Score: 0.93374
# 1000/1000 - 24s - loss: 0.0976 - accuracy: 0.9673 - val_loss: 0.1016 - val_accuracy: 0.9668
# Epoch 29/120
# F1 Macro Score: 0.93570
# 1000/1000 - 23s - loss: 0.0972 - accuracy: 0.9674 - val_loss: 0.0964 - val_accuracy: 0.9678
# Epoch 30/120
# F1 Macro Score: 0.93671
# 1000/1000 - 23s - loss: 0.0949 - accuracy: 0.9676 - val_loss: 0.0918 - val_accuracy: 0.9683
# Epoch 31/120
# F1 Macro Score: 0.93667
# 1000/1000 - 23s - loss: 0.0937 - accuracy: 0.9678 - val_loss: 0.0921 - val_accuracy: 0.9682
# Epoch 32/120
# F1 Macro Score: 0.93718
# 1000/1000 - 23s - loss: 0.0939 - accuracy: 0.9677 - val_loss: 0.0912 - val_accuracy: 0.9684
# Epoch 33/120
# F1 Macro Score: 0.93685
# 1000/1000 - 23s - loss: 0.0937 - accuracy: 0.9677 - val_loss: 0.0915 - val_accuracy: 0.9683
# Epoch 34/120
# F1 Macro Score: 0.93688
# 1000/1000 - 23s - loss: 0.0938 - accuracy: 0.9677 - val_loss: 0.0905 - val_accuracy: 0.9683
# Epoch 35/120
# F1 Macro Score: 0.93699
# 1000/1000 - 23s - loss: 0.0927 - accuracy: 0.9678 - val_loss: 0.0903 - val_accuracy: 0.9684
# Epoch 36/120
# F1 Macro Score: 0.93614
# 1000/1000 - 23s - loss: 0.0979 - accuracy: 0.9669 - val_loss: 0.0962 - val_accuracy: 0.9677
# Epoch 37/120
# F1 Macro Score: 0.93677
# 1000/1000 - 23s - loss: 0.0935 - accuracy: 0.9678 - val_loss: 0.0909 - val_accuracy: 0.9683
# Epoch 38/120
# F1 Macro Score: 0.93636
# 1000/1000 - 22s - loss: 0.0923 - accuracy: 0.9678 - val_loss: 0.0902 - val_accuracy: 0.9683
# Epoch 39/120
# F1 Macro Score: 0.93622
# 1000/1000 - 23s - loss: 0.0920 - accuracy: 0.9678 - val_loss: 0.0909 - val_accuracy: 0.9682
# Epoch 40/120
# F1 Macro Score: 0.93557
# 1000/1000 - 23s - loss: 0.0917 - accuracy: 0.9679 - val_loss: 0.0926 - val_accuracy: 0.9679
# Epoch 41/120
# F1 Macro Score: 0.93654
# 1000/1000 - 23s - loss: 0.0917 - accuracy: 0.9679 - val_loss: 0.0900 - val_accuracy: 0.9682
# Epoch 42/120
# F1 Macro Score: 0.93712
# 1000/1000 - 23s - loss: 0.0909 - accuracy: 0.9680 - val_loss: 0.0888 - val_accuracy: 0.9684
# Epoch 43/120
# F1 Macro Score: 0.93708
# 1000/1000 - 23s - loss: 0.0906 - accuracy: 0.9680 - val_loss: 0.0887 - val_accuracy: 0.9685
# Epoch 44/120
# F1 Macro Score: 0.93622
# 1000/1000 - 23s - loss: 0.0909 - accuracy: 0.9680 - val_loss: 0.0894 - val_accuracy: 0.9683
# Epoch 45/120
# F1 Macro Score: 0.93581
# 1000/1000 - 23s - loss: 0.0911 - accuracy: 0.9679 - val_loss: 0.0910 - val_accuracy: 0.9679
# Epoch 46/120
# F1 Macro Score: 0.93699
# 1000/1000 - 24s - loss: 0.0904 - accuracy: 0.9680 - val_loss: 0.0888 - val_accuracy: 0.9683
# Epoch 47/120
# F1 Macro Score: 0.93648
# 1000/1000 - 23s - loss: 0.0909 - accuracy: 0.9679 - val_loss: 0.0897 - val_accuracy: 0.9682
# Epoch 48/120
# F1 Macro Score: 0.93676
# 1000/1000 - 23s - loss: 0.0908 - accuracy: 0.9679 - val_loss: 0.0885 - val_accuracy: 0.9684
# Epoch 49/120
# F1 Macro Score: 0.93718
# 1000/1000 - 23s - loss: 0.0897 - accuracy: 0.9681 - val_loss: 0.0884 - val_accuracy: 0.9684
# Epoch 50/120
# F1 Macro Score: 0.93677
# 1000/1000 - 23s - loss: 0.0897 - accuracy: 0.9680 - val_loss: 0.0882 - val_accuracy: 0.9684
# Epoch 51/120
# F1 Macro Score: 0.93723
# 1000/1000 - 22s - loss: 0.0892 - accuracy: 0.9681 - val_loss: 0.0878 - val_accuracy: 0.9685
# Epoch 52/120
# F1 Macro Score: 0.93692
# 1000/1000 - 24s - loss: 0.0892 - accuracy: 0.9681 - val_loss: 0.0878 - val_accuracy: 0.9685
# Epoch 53/120
# F1 Macro Score: 0.93703
# 1000/1000 - 23s - loss: 0.0895 - accuracy: 0.9681 - val_loss: 0.0880 - val_accuracy: 0.9685
# Epoch 54/120
# F1 Macro Score: 0.93694
# 1000/1000 - 23s - loss: 0.0894 - accuracy: 0.9680 - val_loss: 0.0878 - val_accuracy: 0.9684
# Epoch 55/120
# F1 Macro Score: 0.93691
# 1000/1000 - 23s - loss: 0.0888 - accuracy: 0.9681 - val_loss: 0.0873 - val_accuracy: 0.9685
# Epoch 56/120
# F1 Macro Score: 0.93635
# 1000/1000 - 23s - loss: 0.0891 - accuracy: 0.9681 - val_loss: 0.0883 - val_accuracy: 0.9683
# Epoch 57/120
# F1 Macro Score: 0.93688
# 1000/1000 - 23s - loss: 0.0893 - accuracy: 0.9681 - val_loss: 0.0879 - val_accuracy: 0.9685
# Epoch 58/120
# F1 Macro Score: 0.93667
# 1000/1000 - 23s - loss: 0.0885 - accuracy: 0.9682 - val_loss: 0.0879 - val_accuracy: 0.9684
# Epoch 59/120
# F1 Macro Score: 0.93663
# 1000/1000 - 23s - loss: 0.0890 - accuracy: 0.9681 - val_loss: 0.0884 - val_accuracy: 0.9684
# Epoch 60/120
# F1 Macro Score: 0.93694
# 1000/1000 - 23s - loss: 0.0885 - accuracy: 0.9682 - val_loss: 0.0876 - val_accuracy: 0.9684
# Epoch 61/120
# F1 Macro Score: 0.93683
# 1000/1000 - 22s - loss: 0.0881 - accuracy: 0.9682 - val_loss: 0.0870 - val_accuracy: 0.9685
# Epoch 62/120
# F1 Macro Score: 0.93713
# 1000/1000 - 25s - loss: 0.0880 - accuracy: 0.9682 - val_loss: 0.0873 - val_accuracy: 0.9684
# Epoch 63/120
# F1 Macro Score: 0.93569
# 1000/1000 - 18s - loss: 0.0880 - accuracy: 0.9682 - val_loss: 0.0897 - val_accuracy: 0.9681
# Epoch 64/120
# F1 Macro Score: 0.93718
# 1000/1000 - 22s - loss: 0.0886 - accuracy: 0.9681 - val_loss: 0.0867 - val_accuracy: 0.9686
# Epoch 65/120
# F1 Macro Score: 0.93696
# 1000/1000 - 23s - loss: 0.0877 - accuracy: 0.9682 - val_loss: 0.0871 - val_accuracy: 0.9685
# Epoch 66/120
# F1 Macro Score: 0.93693
# 1000/1000 - 22s - loss: 0.0879 - accuracy: 0.9681 - val_loss: 0.0866 - val_accuracy: 0.9686
# Epoch 67/120
# F1 Macro Score: 0.93720
# 1000/1000 - 24s - loss: 0.0878 - accuracy: 0.9682 - val_loss: 0.0868 - val_accuracy: 0.9686
# Epoch 68/120
# F1 Macro Score: 0.93717
# 1000/1000 - 23s - loss: 0.0885 - accuracy: 0.9680 - val_loss: 0.0864 - val_accuracy: 0.9686
# Epoch 69/120
# F1 Macro Score: 0.93695
# 1000/1000 - 23s - loss: 0.0895 - accuracy: 0.9678 - val_loss: 0.0882 - val_accuracy: 0.9684
# Epoch 70/120
# F1 Macro Score: 0.93537
# 1000/1000 - 23s - loss: 0.0903 - accuracy: 0.9678 - val_loss: 0.0897 - val_accuracy: 0.9681
# Epoch 71/120
# F1 Macro Score: 0.93621
# 1000/1000 - 23s - loss: 0.0886 - accuracy: 0.9681 - val_loss: 0.0885 - val_accuracy: 0.9682
# Epoch 72/120
# F1 Macro Score: 0.93693
# 1000/1000 - 23s - loss: 0.0881 - accuracy: 0.9681 - val_loss: 0.0867 - val_accuracy: 0.9685
# Epoch 73/120
# F1 Macro Score: 0.93706
# 1000/1000 - 22s - loss: 0.0879 - accuracy: 0.9682 - val_loss: 0.0863 - val_accuracy: 0.9686
# Epoch 74/120
# F1 Macro Score: 0.93708
# 1000/1000 - 23s - loss: 0.0870 - accuracy: 0.9683 - val_loss: 0.0861 - val_accuracy: 0.9686
# Epoch 75/120
# F1 Macro Score: 0.93737
# 1000/1000 - 22s - loss: 0.0873 - accuracy: 0.9683 - val_loss: 0.0861 - val_accuracy: 0.9686
# Epoch 76/120
# F1 Macro Score: 0.93727
# 1000/1000 - 23s - loss: 0.0873 - accuracy: 0.9682 - val_loss: 0.0861 - val_accuracy: 0.9686
# Epoch 77/120
# F1 Macro Score: 0.93721
# 1000/1000 - 23s - loss: 0.0871 - accuracy: 0.9683 - val_loss: 0.0857 - val_accuracy: 0.9686
# Epoch 78/120
# F1 Macro Score: 0.93699
# 1000/1000 - 22s - loss: 0.0870 - accuracy: 0.9683 - val_loss: 0.0862 - val_accuracy: 0.9686
# Epoch 79/120
# F1 Macro Score: 0.93685
# 1000/1000 - 23s - loss: 0.0871 - accuracy: 0.9682 - val_loss: 0.0868 - val_accuracy: 0.9685
# Epoch 80/120
# F1 Macro Score: 0.93725
# 1000/1000 - 23s - loss: 0.0870 - accuracy: 0.9683 - val_loss: 0.0864 - val_accuracy: 0.9685
# Epoch 81/120
# F1 Macro Score: 0.93714
# 1000/1000 - 23s - loss: 0.0866 - accuracy: 0.9684 - val_loss: 0.0857 - val_accuracy: 0.9686
# Epoch 82/120
# F1 Macro Score: 0.93597
# 1000/1000 - 24s - loss: 0.0869 - accuracy: 0.9682 - val_loss: 0.0881 - val_accuracy: 0.9681
# Epoch 83/120
# F1 Macro Score: 0.93740
# 1000/1000 - 23s - loss: 0.0866 - accuracy: 0.9683 - val_loss: 0.0854 - val_accuracy: 0.9687
# Epoch 84/120
# F1 Macro Score: 0.93733
# 1000/1000 - 23s - loss: 0.0865 - accuracy: 0.9683 - val_loss: 0.0855 - val_accuracy: 0.9687
# Epoch 85/120
# F1 Macro Score: 0.93705
# 1000/1000 - 23s - loss: 0.0860 - accuracy: 0.9685 - val_loss: 0.0855 - val_accuracy: 0.9687
# Epoch 86/120
# F1 Macro Score: 0.93621
# 1000/1000 - 23s - loss: 0.0862 - accuracy: 0.9684 - val_loss: 0.0869 - val_accuracy: 0.9683
# Epoch 87/120
# F1 Macro Score: 0.93716
# 1000/1000 - 23s - loss: 0.0867 - accuracy: 0.9683 - val_loss: 0.0856 - val_accuracy: 0.9686
# Epoch 88/120
# F1 Macro Score: 0.93715
# 1000/1000 - 24s - loss: 0.0861 - accuracy: 0.9684 - val_loss: 0.0853 - val_accuracy: 0.9687
# Epoch 89/120
# F1 Macro Score: 0.93623
# 1000/1000 - 23s - loss: 0.0860 - accuracy: 0.9684 - val_loss: 0.0876 - val_accuracy: 0.9681
# Epoch 90/120
# F1 Macro Score: 0.93715
# 1000/1000 - 22s - loss: 0.0856 - accuracy: 0.9685 - val_loss: 0.0851 - val_accuracy: 0.9687
# Epoch 91/120
# F1 Macro Score: 0.93743
# 1000/1000 - 22s - loss: 0.0856 - accuracy: 0.9685 - val_loss: 0.0847 - val_accuracy: 0.9687
# Epoch 92/120
# F1 Macro Score: 0.93701
# 1000/1000 - 23s - loss: 0.0854 - accuracy: 0.9685 - val_loss: 0.0853 - val_accuracy: 0.9686
# Epoch 93/120
# F1 Macro Score: 0.93720
# 1000/1000 - 23s - loss: 0.0855 - accuracy: 0.9685 - val_loss: 0.0849 - val_accuracy: 0.9687
# Epoch 94/120
# F1 Macro Score: 0.93683
# 1000/1000 - 23s - loss: 0.0856 - accuracy: 0.9685 - val_loss: 0.0860 - val_accuracy: 0.9684
# Epoch 95/120
# F1 Macro Score: 0.93720
# 1000/1000 - 23s - loss: 0.0855 - accuracy: 0.9685 - val_loss: 0.0851 - val_accuracy: 0.9686
# Epoch 96/120
# F1 Macro Score: 0.93735
# 1000/1000 - 23s - loss: 0.0851 - accuracy: 0.9685 - val_loss: 0.0847 - val_accuracy: 0.9687
# Epoch 97/120
# F1 Macro Score: 0.93675
# 1000/1000 - 23s - loss: 0.0851 - accuracy: 0.9685 - val_loss: 0.0853 - val_accuracy: 0.9685
# Epoch 98/120
# F1 Macro Score: 0.93728
# 1000/1000 - 23s - loss: 0.0852 - accuracy: 0.9685 - val_loss: 0.0846 - val_accuracy: 0.9687
# Epoch 99/120
# F1 Macro Score: 0.93715
# 1000/1000 - 23s - loss: 0.0852 - accuracy: 0.9686 - val_loss: 0.0851 - val_accuracy: 0.9686
# Epoch 100/120
# F1 Macro Score: 0.93730
# 1000/1000 - 22s - loss: 0.0861 - accuracy: 0.9683 - val_loss: 0.0852 - val_accuracy: 0.9686
# Epoch 101/120
# F1 Macro Score: 0.93733
# 1000/1000 - 23s - loss: 0.0849 - accuracy: 0.9686 - val_loss: 0.0845 - val_accuracy: 0.9688
# Epoch 102/120
# F1 Macro Score: 0.93733
# 1000/1000 - 23s - loss: 0.0848 - accuracy: 0.9687 - val_loss: 0.0844 - val_accuracy: 0.9688
# Epoch 103/120
# F1 Macro Score: 0.93755
# 1000/1000 - 23s - loss: 0.0850 - accuracy: 0.9686 - val_loss: 0.0842 - val_accuracy: 0.9688
# Epoch 104/120
# F1 Macro Score: 0.93768
# 1000/1000 - 23s - loss: 0.0845 - accuracy: 0.9687 - val_loss: 0.0841 - val_accuracy: 0.9688
# Epoch 105/120
# F1 Macro Score: 0.93751
# 1000/1000 - 22s - loss: 0.0843 - accuracy: 0.9688 - val_loss: 0.0841 - val_accuracy: 0.9688
# Epoch 106/120
# F1 Macro Score: 0.93755
# 1000/1000 - 23s - loss: 0.0847 - accuracy: 0.9687 - val_loss: 0.0841 - val_accuracy: 0.9688
# Epoch 107/120
# F1 Macro Score: 0.93771
# 1000/1000 - 23s - loss: 0.0842 - accuracy: 0.9687 - val_loss: 0.0841 - val_accuracy: 0.9688
# Epoch 108/120
# F1 Macro Score: 0.93761
# 1000/1000 - 23s - loss: 0.0845 - accuracy: 0.9687 - val_loss: 0.0841 - val_accuracy: 0.9688
# Epoch 109/120
# F1 Macro Score: 0.93760
# 1000/1000 - 23s - loss: 0.0842 - accuracy: 0.9688 - val_loss: 0.0840 - val_accuracy: 0.9688
# Epoch 110/120
# F1 Macro Score: 0.93742
# 1000/1000 - 23s - loss: 0.0845 - accuracy: 0.9687 - val_loss: 0.0841 - val_accuracy: 0.9688
# Epoch 111/120
# F1 Macro Score: 0.93755
# 1000/1000 - 23s - loss: 0.0843 - accuracy: 0.9687 - val_loss: 0.0840 - val_accuracy: 0.9688
# Epoch 112/120
# F1 Macro Score: 0.93759
# 1000/1000 - 23s - loss: 0.0842 - accuracy: 0.9688 - val_loss: 0.0841 - val_accuracy: 0.9688
# Epoch 113/120
# F1 Macro Score: 0.93747
# 1000/1000 - 22s - loss: 0.0839 - accuracy: 0.9688 - val_loss: 0.0841 - val_accuracy: 0.9688
# Epoch 114/120
# F1 Macro Score: 0.93745
# 1000/1000 - 18s - loss: 0.0844 - accuracy: 0.9687 - val_loss: 0.0842 - val_accuracy: 0.9687
# Epoch 115/120
# F1 Macro Score: 0.93740
# 1000/1000 - 22s - loss: 0.0839 - accuracy: 0.9688 - val_loss: 0.0842 - val_accuracy: 0.9688
# Epoch 116/120
# F1 Macro Score: 0.93738
# 1000/1000 - 23s - loss: 0.0842 - accuracy: 0.9688 - val_loss: 0.0841 - val_accuracy: 0.9688
# Epoch 117/120
# F1 Macro Score: 0.93766
# 1000/1000 - 23s - loss: 0.0839 - accuracy: 0.9688 - val_loss: 0.0840 - val_accuracy: 0.9688
# Epoch 118/120
# F1 Macro Score: 0.93748
# 1000/1000 - 22s - loss: 0.0844 - accuracy: 0.9687 - val_loss: 0.0839 - val_accuracy: 0.9688
# Epoch 119/120
# F1 Macro Score: 0.93746
# 1000/1000 - 22s - loss: 0.0848 - accuracy: 0.9687 - val_loss: 0.0840 - val_accuracy: 0.9688
# Epoch 120/120
# F1 Macro Score: 0.93747
# 1000/1000 - 23s - loss: 0.0839 - accuracy: 0.9688 - val_loss: 0.0840 - val_accuracy: 0.9688
# Training fold 3 completed. macro f1 score : 0.93747
# Our training dataset shape is (1000, 4000, 19)
# Our validation dataset shape is (250, 4000, 19)
# Train on 1000 samples, validate on 250 samples
# Epoch 1/120
# F1 Macro Score: 0.46173
# 1000/1000 - 121s - loss: 0.6836 - accuracy: 0.7662 - val_loss: 1.1716 - val_accuracy: 0.7293
# Epoch 2/120
# F1 Macro Score: 0.65065
# ...
# Epoch 120/120
# F1 Macro Score: 0.93772
# 1000/1000 - 17s - loss: 0.0834 - accuracy: 0.9689 - val_loss: 0.0865 - val_accuracy: 0.9678
# Training fold 4 completed. macro f1 score : 0.93772
# Our training dataset shape is (1000, 4000, 19)
# Our validation dataset shape is (250, 4000, 19)
# Train on 1000 samples, validate on 250 samples
# Epoch 1/120
# F1 Macro Score: 0.41909
# 1000/1000 - 65s - loss: 0.6742 - accuracy: 0.7725 - val_loss: 3.8091 - val_accuracy: 0.6980
# Epoch 2/120
# F1 Macro Score: 0.58044
# 1000/1000 - 17s - loss: 0.2435 - accuracy: 0.9271 - val_loss: 0.8143 - val_accuracy: 0.7763
# Epoch 3/120
# F1 Macro Score: 0.89175
# 1000/1000 - 16s - loss: 0.1403 - accuracy: 0.9614 - val_loss: 0.3359 - val_accuracy: 0.9506
# Epoch 4/120
# F1 Macro Score: 0.93150
# 1000/1000 - 17s - loss: 0.1165 - accuracy: 0.9658 - val_loss: 0.1785 - val_accuracy: 0.9639
# Epoch 5/120
# F1 Macro Score: 0.93166
# 1000/1000 - 17s - loss: 0.1098 - accuracy: 0.9665 - val_loss: 0.1352 - val_accuracy: 0.9655
# Epoch 6/120
# F1 Macro Score: 0.93520
# 1000/1000 - 16s - loss: 0.1071 - accuracy: 0.9669 - val_loss: 0.1144 - val_accuracy: 0.9664
# Epoch 7/120
# F1 Macro Score: 0.93632
# 1000/1000 - 17s - loss: 0.1023 - accuracy: 0.9674 - val_loss: 0.1017 - val_accuracy: 0.9670
# Epoch 8/120
# F1 Macro Score: 0.93692
# 1000/1000 - 17s - loss: 0.0995 - accuracy: 0.9676 - val_loss: 0.0988 - val_accuracy: 0.9673
# Epoch 9/120
# F1 Macro Score: 0.93048
# 1000/1000 - 17s - loss: 0.0993 - accuracy: 0.9676 - val_loss: 0.1098 - val_accuracy: 0.9648
# Epoch 10/120
# F1 Macro Score: 0.93620
# 1000/1000 - 16s - loss: 0.0984 - accuracy: 0.9676 - val_loss: 0.1090 - val_accuracy: 0.9668
# Epoch 11/120
# F1 Macro Score: 0.69760
# 1000/1000 - 16s - loss: 0.1296 - accuracy: 0.9618 - val_loss: 0.9295 - val_accuracy: 0.7117
# Epoch 12/120
# F1 Macro Score: 0.48065
# 1000/1000 - 16s - loss: 0.1260 - accuracy: 0.9631 - val_loss: 3.3979 - val_accuracy: 0.7531
# Epoch 13/120
# F1 Macro Score: 0.35753
# 1000/1000 - 16s - loss: 0.2232 - accuracy: 0.9369 - val_loss: 5.1099 - val_accuracy: 0.4911
# Epoch 14/120
# F1 Macro Score: 0.60599
# 1000/1000 - 17s - loss: 0.1558 - accuracy: 0.9566 - val_loss: 1.5156 - val_accuracy: 0.8171
# Epoch 15/120
# F1 Macro Score: 0.90158
# 1000/1000 - 17s - loss: 0.1177 - accuracy: 0.9652 - val_loss: 0.1454 - val_accuracy: 0.9583
# Epoch 16/120
# F1 Macro Score: 0.93257
# 1000/1000 - 17s - loss: 0.1058 - accuracy: 0.9670 - val_loss: 0.1085 - val_accuracy: 0.9660
# Epoch 17/120
# F1 Macro Score: 0.93708
# 1000/1000 - 16s - loss: 0.1018 - accuracy: 0.9673 - val_loss: 0.0997 - val_accuracy: 0.9673
# Epoch 18/120
# F1 Macro Score: 0.93272
# 1000/1000 - 17s - loss: 0.1019 - accuracy: 0.9673 - val_loss: 0.1251 - val_accuracy: 0.9590
# Epoch 19/120
# F1 Macro Score: 0.93692
# 1000/1000 - 16s - loss: 0.1025 - accuracy: 0.9672 - val_loss: 0.0983 - val_accuracy: 0.9673
# Epoch 20/120
# F1 Macro Score: 0.93604
# 1000/1000 - 17s - loss: 0.1001 - accuracy: 0.9674 - val_loss: 0.0983 - val_accuracy: 0.9670
# Epoch 21/120
# F1 Macro Score: 0.93722
# 1000/1000 - 17s - loss: 0.0962 - accuracy: 0.9679 - val_loss: 0.0956 - val_accuracy: 0.9674
# Epoch 22/120
# F1 Macro Score: 0.93727
# 1000/1000 - 16s - loss: 0.0953 - accuracy: 0.9679 - val_loss: 0.0946 - val_accuracy: 0.9674
# Epoch 23/120
# F1 Macro Score: 0.93710
# 1000/1000 - 16s - loss: 0.0950 - accuracy: 0.9679 - val_loss: 0.0948 - val_accuracy: 0.9674
# Epoch 24/120
# F1 Macro Score: 0.93681
# 1000/1000 - 17s - loss: 0.0962 - accuracy: 0.9677 - val_loss: 0.0961 - val_accuracy: 0.9672
# Epoch 25/120
# F1 Macro Score: 0.93699
# 1000/1000 - 17s - loss: 0.0939 - accuracy: 0.9679 - val_loss: 0.0943 - val_accuracy: 0.9674
# Epoch 26/120
# F1 Macro Score: 0.93675
# 1000/1000 - 17s - loss: 0.0929 - accuracy: 0.9680 - val_loss: 0.0936 - val_accuracy: 0.9674
# Epoch 27/120
# F1 Macro Score: 0.93706
# 1000/1000 - 17s - loss: 0.0926 - accuracy: 0.9679 - val_loss: 0.0933 - val_accuracy: 0.9675
# Epoch 28/120
# F1 Macro Score: 0.93632
# 1000/1000 - 17s - loss: 0.0915 - accuracy: 0.9681 - val_loss: 0.0923 - val_accuracy: 0.9674
# Epoch 29/120
# F1 Macro Score: 0.93611
# 1000/1000 - 17s - loss: 0.0917 - accuracy: 0.9680 - val_loss: 0.0939 - val_accuracy: 0.9671
# Epoch 30/120
# F1 Macro Score: 0.93612
# 1000/1000 - 17s - loss: 0.0908 - accuracy: 0.9682 - val_loss: 0.0932 - val_accuracy: 0.9672
# Epoch 31/120
# F1 Macro Score: 0.93752
# 1000/1000 - 17s - loss: 0.0895 - accuracy: 0.9683 - val_loss: 0.0902 - val_accuracy: 0.9677
# Epoch 32/120
# F1 Macro Score: 0.93767
# 1000/1000 - 17s - loss: 0.0891 - accuracy: 0.9684 - val_loss: 0.0897 - val_accuracy: 0.9677
# Epoch 33/120
# F1 Macro Score: 0.93671
# 1000/1000 - 17s - loss: 0.0890 - accuracy: 0.9685 - val_loss: 0.0917 - val_accuracy: 0.9674
# Epoch 34/120
# F1 Macro Score: 0.93760
# 1000/1000 - 17s - loss: 0.0886 - accuracy: 0.9684 - val_loss: 0.0892 - val_accuracy: 0.9678
# Epoch 35/120
# F1 Macro Score: 0.93743
# 1000/1000 - 17s - loss: 0.0883 - accuracy: 0.9685 - val_loss: 0.0891 - val_accuracy: 0.9677
# Epoch 36/120
# F1 Macro Score: 0.93627
# 1000/1000 - 16s - loss: 0.0903 - accuracy: 0.9681 - val_loss: 0.0927 - val_accuracy: 0.9669
# Epoch 37/120
# F1 Macro Score: 0.93746
# 1000/1000 - 17s - loss: 0.0883 - accuracy: 0.9684 - val_loss: 0.0894 - val_accuracy: 0.9676
# Epoch 38/120
# F1 Macro Score: 0.93666
# 1000/1000 - 17s - loss: 0.0872 - accuracy: 0.9686 - val_loss: 0.0902 - val_accuracy: 0.9674
# Epoch 39/120
# F1 Macro Score: 0.93770
# 1000/1000 - 17s - loss: 0.0874 - accuracy: 0.9686 - val_loss: 0.0887 - val_accuracy: 0.9678
# Epoch 40/120
# F1 Macro Score: 0.93763
# 1000/1000 - 17s - loss: 0.0867 - accuracy: 0.9688 - val_loss: 0.0889 - val_accuracy: 0.9678
# Epoch 41/120
# F1 Macro Score: 0.93750
# 1000/1000 - 17s - loss: 0.0869 - accuracy: 0.9687 - val_loss: 0.0886 - val_accuracy: 0.9677
# Epoch 42/120
# F1 Macro Score: 0.93776
# 1000/1000 - 17s - loss: 0.0854 - accuracy: 0.9690 - val_loss: 0.0881 - val_accuracy: 0.9678
# Epoch 43/120
# F1 Macro Score: 0.93756
# 1000/1000 - 17s - loss: 0.0853 - accuracy: 0.9690 - val_loss: 0.0877 - val_accuracy: 0.9678
# Epoch 44/120
# F1 Macro Score: 0.93751
# 1000/1000 - 17s - loss: 0.0850 - accuracy: 0.9692 - val_loss: 0.0881 - val_accuracy: 0.9677
# Epoch 45/120
# F1 Macro Score: 0.93722
# 1000/1000 - 17s - loss: 0.0849 - accuracy: 0.9692 - val_loss: 0.0880 - val_accuracy: 0.9677
# Epoch 46/120
# F1 Macro Score: 0.93779
# 1000/1000 - 17s - loss: 0.0840 - accuracy: 0.9694 - val_loss: 0.0878 - val_accuracy: 0.9678
# Epoch 47/120
# F1 Macro Score: 0.93747
# 1000/1000 - 17s - loss: 0.0837 - accuracy: 0.9695 - val_loss: 0.0877 - val_accuracy: 0.9679
# Epoch 48/120
# F1 Macro Score: 0.93770
# 1000/1000 - 17s - loss: 0.0833 - accuracy: 0.9697 - val_loss: 0.0881 - val_accuracy: 0.9678
# Epoch 49/120
# F1 Macro Score: 0.93708
# 1000/1000 - 17s - loss: 0.0822 - accuracy: 0.9699 - val_loss: 0.0883 - val_accuracy: 0.9676
# Epoch 50/120
# F1 Macro Score: 0.93797
# 1000/1000 - 17s - loss: 0.0825 - accuracy: 0.9699 - val_loss: 0.0870 - val_accuracy: 0.9679
# Epoch 51/120
# F1 Macro Score: 0.93714
# 1000/1000 - 17s - loss: 0.0813 - accuracy: 0.9702 - val_loss: 0.0883 - val_accuracy: 0.9677
# Epoch 52/120
# F1 Macro Score: 0.93732
# 1000/1000 - 17s - loss: 0.0807 - accuracy: 0.9704 - val_loss: 0.0877 - val_accuracy: 0.9677
# Epoch 53/120
# F1 Macro Score: 0.93754
# 1000/1000 - 17s - loss: 0.0804 - accuracy: 0.9705 - val_loss: 0.0876 - val_accuracy: 0.9678
# Epoch 54/120
# F1 Macro Score: 0.93716
# 1000/1000 - 16s - loss: 0.0796 - accuracy: 0.9708 - val_loss: 0.0880 - val_accuracy: 0.9677
# Epoch 55/120
# F1 Macro Score: 0.93711
# 1000/1000 - 17s - loss: 0.0786 - accuracy: 0.9711 - val_loss: 0.0882 - val_accuracy: 0.9676
# Epoch 56/120
# F1 Macro Score: 0.93656
# 1000/1000 - 17s - loss: 0.0779 - accuracy: 0.9713 - val_loss: 0.0888 - val_accuracy: 0.9676
# Epoch 57/120
# F1 Macro Score: 0.93691
# 1000/1000 - 17s - loss: 0.0771 - accuracy: 0.9716 - val_loss: 0.0889 - val_accuracy: 0.9675
# Epoch 58/120
# F1 Macro Score: 0.93629
# 1000/1000 - 17s - loss: 0.0755 - accuracy: 0.9720 - val_loss: 0.0897 - val_accuracy: 0.9673
# Epoch 59/120
# F1 Macro Score: 0.93456
# 1000/1000 - 17s - loss: 0.0748 - accuracy: 0.9722 - val_loss: 0.0931 - val_accuracy: 0.9667
# Epoch 60/120
# F1 Macro Score: 0.93622
# 1000/1000 - 17s - loss: 0.0732 - accuracy: 0.9728 - val_loss: 0.0906 - val_accuracy: 0.9672
# Epoch 61/120
# F1 Macro Score: 0.93618
# 1000/1000 - 17s - loss: 0.0709 - accuracy: 0.9735 - val_loss: 0.0911 - val_accuracy: 0.9672
# Epoch 62/120
# F1 Macro Score: 0.93472
# 1000/1000 - 17s - loss: 0.0696 - accuracy: 0.9740 - val_loss: 0.0940 - val_accuracy: 0.9664
# Epoch 63/120
# F1 Macro Score: 0.93473
# 1000/1000 - 17s - loss: 0.0677 - accuracy: 0.9746 - val_loss: 0.0945 - val_accuracy: 0.9664
# Epoch 64/120
# F1 Macro Score: 0.93570
# 1000/1000 - 17s - loss: 0.0668 - accuracy: 0.9750 - val_loss: 0.0939 - val_accuracy: 0.9667
# Epoch 65/120
# F1 Macro Score: 0.93533
# 1000/1000 - 17s - loss: 0.0643 - accuracy: 0.9758 - val_loss: 0.0950 - val_accuracy: 0.9666
# Epoch 66/120
# F1 Macro Score: 0.93481
# 1000/1000 - 17s - loss: 0.0632 - accuracy: 0.9762 - val_loss: 0.0971 - val_accuracy: 0.9663
# Epoch 67/120
# F1 Macro Score: 0.93447
# 1000/1000 - 17s - loss: 0.0615 - accuracy: 0.9769 - val_loss: 0.0981 - val_accuracy: 0.9661
# Epoch 68/120
# F1 Macro Score: 0.92609
# 1000/1000 - 16s - loss: 0.0615 - accuracy: 0.9771 - val_loss: 0.1124 - val_accuracy: 0.9634
# Epoch 69/120
# F1 Macro Score: 0.93042
# 1000/1000 - 17s - loss: 0.0642 - accuracy: 0.9760 - val_loss: 0.1066 - val_accuracy: 0.9649
# Epoch 70/120
# F1 Macro Score: 0.93205
# 1000/1000 - 16s - loss: 0.0593 - accuracy: 0.9777 - val_loss: 0.1007 - val_accuracy: 0.9655
# Epoch 71/120
# F1 Macro Score: 0.93410
# 1000/1000 - 17s - loss: 0.0566 - accuracy: 0.9788 - val_loss: 0.0997 - val_accuracy: 0.9660
# Epoch 72/120
# F1 Macro Score: 0.93363
# 1000/1000 - 17s - loss: 0.0542 - accuracy: 0.9797 - val_loss: 0.1009 - val_accuracy: 0.9657
# Epoch 73/120
# F1 Macro Score: 0.93302
# 1000/1000 - 17s - loss: 0.0528 - accuracy: 0.9803 - val_loss: 0.1040 - val_accuracy: 0.9654
# Epoch 74/120
# F1 Macro Score: 0.93235
# 1000/1000 - 17s - loss: 0.0507 - accuracy: 0.9811 - val_loss: 0.1050 - val_accuracy: 0.9651
# Epoch 75/120
# F1 Macro Score: 0.93201
# 1000/1000 - 17s - loss: 0.0500 - accuracy: 0.9814 - val_loss: 0.1084 - val_accuracy: 0.9649
# Epoch 76/120
# F1 Macro Score: 0.93189
# 1000/1000 - 17s - loss: 0.0496 - accuracy: 0.9816 - val_loss: 0.1090 - val_accuracy: 0.9649
# Epoch 77/120
# F1 Macro Score: 0.93178
# 1000/1000 - 17s - loss: 0.0474 - accuracy: 0.9824 - val_loss: 0.1096 - val_accuracy: 0.9648
# Epoch 78/120
# F1 Macro Score: 0.93120
# 1000/1000 - 17s - loss: 0.0461 - accuracy: 0.9830 - val_loss: 0.1111 - val_accuracy: 0.9646
# Epoch 79/120
# F1 Macro Score: 0.93099
# 1000/1000 - 17s - loss: 0.0448 - accuracy: 0.9835 - val_loss: 0.1128 - val_accuracy: 0.9645
# Epoch 80/120
# F1 Macro Score: 0.93020
# 1000/1000 - 17s - loss: 0.0432 - accuracy: 0.9842 - val_loss: 0.1141 - val_accuracy: 0.9641
# Epoch 81/120
# F1 Macro Score: 0.93012
# 1000/1000 - 17s - loss: 0.0413 - accuracy: 0.9850 - val_loss: 0.1171 - val_accuracy: 0.9642
# Epoch 82/120
# F1 Macro Score: 0.92850
# 1000/1000 - 17s - loss: 0.0400 - accuracy: 0.9856 - val_loss: 0.1191 - val_accuracy: 0.9637
# Epoch 83/120
# F1 Macro Score: 0.92905
# 1000/1000 - 17s - loss: 0.0398 - accuracy: 0.9856 - val_loss: 0.1214 - val_accuracy: 0.9638
# Epoch 84/120
# F1 Macro Score: 0.92836
# 1000/1000 - 17s - loss: 0.0383 - accuracy: 0.9863 - val_loss: 0.1217 - val_accuracy: 0.9633
# Epoch 85/120
# F1 Macro Score: 0.92929
# 1000/1000 - 17s - loss: 0.0366 - accuracy: 0.9870 - val_loss: 0.1239 - val_accuracy: 0.9635
# Epoch 86/120
# F1 Macro Score: 0.92852
# 1000/1000 - 17s - loss: 0.0357 - accuracy: 0.9873 - val_loss: 0.1254 - val_accuracy: 0.9633
# Epoch 87/120
# F1 Macro Score: 0.92759
# 1000/1000 - 16s - loss: 0.0355 - accuracy: 0.9875 - val_loss: 0.1273 - val_accuracy: 0.9630
# Epoch 88/120
# F1 Macro Score: 0.92851
# 1000/1000 - 17s - loss: 0.0333 - accuracy: 0.9884 - val_loss: 0.1285 - val_accuracy: 0.9633
# Epoch 89/120
# F1 Macro Score: 0.92701
# 1000/1000 - 17s - loss: 0.0331 - accuracy: 0.9884 - val_loss: 0.1318 - val_accuracy: 0.9627
# Epoch 90/120
# F1 Macro Score: 0.92817
# 1000/1000 - 17s - loss: 0.0310 - accuracy: 0.9893 - val_loss: 0.1313 - val_accuracy: 0.9631
# Epoch 91/120
# F1 Macro Score: 0.92688
# 1000/1000 - 16s - loss: 0.0300 - accuracy: 0.9898 - val_loss: 0.1358 - val_accuracy: 0.9628
# Epoch 92/120
# F1 Macro Score: 0.92654
# 1000/1000 - 17s - loss: 0.0292 - accuracy: 0.9901 - val_loss: 0.1370 - val_accuracy: 0.9625
# Epoch 93/120
# F1 Macro Score: 0.92671
# 1000/1000 - 17s - loss: 0.0286 - accuracy: 0.9904 - val_loss: 0.1383 - val_accuracy: 0.9625
# Epoch 94/120
# F1 Macro Score: 0.92612
# 1000/1000 - 17s - loss: 0.0283 - accuracy: 0.9905 - val_loss: 0.1396 - val_accuracy: 0.9622
# Epoch 95/120
# F1 Macro Score: 0.92581
# 1000/1000 - 17s - loss: 0.0275 - accuracy: 0.9908 - val_loss: 0.1427 - val_accuracy: 0.9620
# Epoch 96/120
# F1 Macro Score: 0.92667
# 1000/1000 - 17s - loss: 0.0255 - accuracy: 0.9917 - val_loss: 0.1411 - val_accuracy: 0.9625
# Epoch 97/120
# F1 Macro Score: 0.92626
# 1000/1000 - 16s - loss: 0.0243 - accuracy: 0.9922 - val_loss: 0.1434 - val_accuracy: 0.9625
# Epoch 98/120
# F1 Macro Score: 0.92543
# 1000/1000 - 17s - loss: 0.0240 - accuracy: 0.9923 - val_loss: 0.1490 - val_accuracy: 0.9619
# Epoch 99/120
# F1 Macro Score: 0.92566
# 1000/1000 - 17s - loss: 0.0240 - accuracy: 0.9923 - val_loss: 0.1495 - val_accuracy: 0.9619
# Epoch 100/120
# F1 Macro Score: 0.92375
# 1000/1000 - 17s - loss: 0.0238 - accuracy: 0.9922 - val_loss: 0.1525 - val_accuracy: 0.9612
# Epoch 101/120
# F1 Macro Score: 0.92552
# 1000/1000 - 16s - loss: 0.0211 - accuracy: 0.9936 - val_loss: 0.1516 - val_accuracy: 0.9620
# Epoch 102/120
# F1 Macro Score: 0.92558
# 1000/1000 - 17s - loss: 0.0203 - accuracy: 0.9940 - val_loss: 0.1508 - val_accuracy: 0.9620
# Epoch 103/120
# F1 Macro Score: 0.92572
# 1000/1000 - 17s - loss: 0.0205 - accuracy: 0.9940 - val_loss: 0.1520 - val_accuracy: 0.9621
# Epoch 104/120
# F1 Macro Score: 0.92545
# 1000/1000 - 17s - loss: 0.0198 - accuracy: 0.9943 - val_loss: 0.1523 - val_accuracy: 0.9620
# Epoch 105/120
# F1 Macro Score: 0.92543
# 1000/1000 - 17s - loss: 0.0189 - accuracy: 0.9948 - val_loss: 0.1534 - val_accuracy: 0.9620
# Epoch 106/120
# F1 Macro Score: 0.92513
# 1000/1000 - 17s - loss: 0.0202 - accuracy: 0.9941 - val_loss: 0.1541 - val_accuracy: 0.9618
# Epoch 107/120
# F1 Macro Score: 0.92513
# 1000/1000 - 17s - loss: 0.0187 - accuracy: 0.9948 - val_loss: 0.1551 - val_accuracy: 0.9618
# Epoch 108/120
# F1 Macro Score: 0.92512
# 1000/1000 - 17s - loss: 0.0186 - accuracy: 0.9949 - val_loss: 0.1555 - val_accuracy: 0.9618
# Epoch 109/120
# F1 Macro Score: 0.92496
# 1000/1000 - 17s - loss: 0.0188 - accuracy: 0.9948 - val_loss: 0.1562 - val_accuracy: 0.9617
# Epoch 110/120
# F1 Macro Score: 0.92482
# 1000/1000 - 17s - loss: 0.0191 - accuracy: 0.9946 - val_loss: 0.1563 - val_accuracy: 0.9616
# Epoch 111/120
# F1 Macro Score: 0.92476
# 1000/1000 - 17s - loss: 0.0185 - accuracy: 0.9949 - val_loss: 0.1573 - val_accuracy: 0.9616
# Epoch 112/120
# F1 Macro Score: 0.92507
# 1000/1000 - 16s - loss: 0.0184 - accuracy: 0.9949 - val_loss: 0.1577 - val_accuracy: 0.9618
# Epoch 113/120
# F1 Macro Score: 0.92484
# 1000/1000 - 17s - loss: 0.0176 - accuracy: 0.9953 - val_loss: 0.1585 - val_accuracy: 0.9617
# Epoch 114/120
# F1 Macro Score: 0.92459
# 1000/1000 - 17s - loss: 0.0182 - accuracy: 0.9950 - val_loss: 0.1595 - val_accuracy: 0.9616
# Epoch 115/120
# F1 Macro Score: 0.92446
# 1000/1000 - 17s - loss: 0.0174 - accuracy: 0.9954 - val_loss: 0.1601 - val_accuracy: 0.9615
# Epoch 116/120
# F1 Macro Score: 0.92435
# 1000/1000 - 17s - loss: 0.0175 - accuracy: 0.9953 - val_loss: 0.1594 - val_accuracy: 0.9615
# Epoch 117/120
# F1 Macro Score: 0.92454
# 1000/1000 - 17s - loss: 0.0172 - accuracy: 0.9955 - val_loss: 0.1598 - val_accuracy: 0.9615
# Epoch 118/120
# F1 Macro Score: 0.92455
# 1000/1000 - 17s - loss: 0.0184 - accuracy: 0.9948 - val_loss: 0.1601 - val_accuracy: 0.9615
# Epoch 119/120
# F1 Macro Score: 0.92472
# 1000/1000 - 17s - loss: 0.0183 - accuracy: 0.9949 - val_loss: 0.1602 - val_accuracy: 0.9615
# Epoch 120/120
# F1 Macro Score: 0.92444
# 1000/1000 - 17s - loss: 0.0170 - accuracy: 0.9955 - val_loss: 0.1619 - val_accuracy: 0.9615
# Training fold 5 completed. macro f1 score : 0.92444
# Training completed. oof macro f1 score : 0.93536
# Training completed...
